# %% [markdown]
# <a href="https://colab.research.google.com/github/Prathamesh-Shanbhag/Week4-Neural_Network/blob/Week4_Assignment_Prathamesh_Shanbhag/Week4__Neural_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# <center><h1> Introduction to Audio Classification with Neural Networks for RAVDESS Only</h1></center>
#
# # Abstract
#
# ### Purpose
# This notebook serves as an introduction to working with audio data for classification problems; it is meant as a learning resource rather than a demonstration of the state-of-the-art. The techniques mentioned in this notebook apply not only to classification problems, but to regression problems and problems dealing with other types of input data as well. I focus particularly on feature engineering techniques for audio data and provide an in-depth look at the logic, concepts, and properties of the Multilayer Perceptron (MLP) model, an ancestor and the origin of deep neural networks (DNNs) today. I also provide an introduction to a few key machine learning models and the logic in choosing their hyperparameters. These objectives are framed by the task of recognizing emotion from snippets of speech audio.
#
# ### Summary
# Data cleansing and feature engineering comprise the most crucial aspect of preparing machine and deep learning models alike and is often the difference between success and failure. We can drastically improve the performance of a model with proper attention paid to feature engineering. This stands for input data which is already useable for predictions; even such data can be transformed in myriad ways to improve predictive performance. For features to be useful in classification they must encompass sufficient variance between different classes. We can further improve the performance of our models by understanding the influence of and precisely tuning their hyperparameters, for which there are algorithmic aids such as Grid Search.
#
# Network architecture is a critical factor in determining the computational complexity of DNNs; often, however, simpler models with just one hidden layer perform better than more complicated models. The importance of proper model evaluation cannot be overstressed: training data should be used strictly for training a model, validation data strictly for tuning a model, and test data strictly to evaluate a model once it is tuned - a model should never be tuned to perform better on test data. To this end, K-Fold Cross Validation is a staple tool.
#
# ### Conclusions
# Classic machine learning models such as Support Vector Machines (SVM), k Nearest Neighbours (kNN), and Random Forests have distinct advantages to deep neural networks in many tasks but do not match the performance of even the simplest deep neural network in the task of audio classification. The Multilayer Perceptron (MLP) model is the simplest form of DNN suited to classification tasks, provides decent off-the-shelf performance, and can be precisely tuned to be accurate and relatively quick to train.
#
# The MLP provides appreciable accuracy on the RAVDESS dataset, but suffers from the relatively small number of training samples afforded by this dataset. Long Short Term Memory Recurrent Neural Networks (LSTM RNNs) and Convolutional Neural Networks (CNNs) are excellent DNN candidates for audio data classification: LSTM RNNs because of their excellent ability to interpret sequential data such as the audio waveform represented as a time series, and CNNs because features engineered on audio data such as spectrograms have marked resemblance to images, in which CNNs excel at recognition and discrimination between distinct patterns.

# %% [markdown]
# <!--TABLE OF CONTENTS-->
#
#
# # Table of Contents
#   - [Intro: Speech Emotion Recognition on the RAVDESS dataset](#Intro:-Speech-Emotion-Recognition-on-the-RAVDESS-dataset)
#   - [Machine Learning Process Overview](#Machine-Learning-Process-Overview)
#   - [Feature Extraction](#Feature-Extraction)
#     - [Load the Dataset and Compute Features](#Load-the-Dataset-and-Compute-Features)
#     - [Feature Scaling](#Feature-Scaling)
#   - [The MLP Model for Classification](#The-MLP-Model-for-Classification)
#     - [Choice of Hyperparameters](#Choice-of-Hyperparameters)
#     - [Network Architecture](#Network-Architecture)
#     - [Hyperparameter Optimization and Grid Search](#Hyperparameter-Optimization-and-Grid-Search)
#   - [Training and Evaluating the MLP Model](#Training-and-Evaluating-the-MLP-Model)
#     - [The Confusion Matrix](#The-Confusion-Matrix)
#     - [Precision, Recall, F-Score](#Precision,-Recall,-F-Score)
#     - [K-Fold Cross-Validation](#K-Fold-Cross-Validation)
#     - [The Validation Curve: Further Tuning of Hyperparameters](#The-Validation-Curve:-Further-Tuning-of-Hyperparameters)
#     - [The Learning Curve: Determining Optimal Training Set Size](#The-Learning-Curve:-Determining-Optimal-Training-Set-Size)
#   - [Higher Complexity DNNs](#Higher-Complexity-DNNs)

# %% [markdown]
# ## Intro: Speech Emotion Recognition on the RAVDESS dataset
# In this notebook we explore the most common machine learning models, specifically those available off the shelf in scikit-learn. After benchmarking performance with machine learning models, we train a Multilayer Perceptron (MLP) model for classification in an attempt to recognize the emotion conveyed in a speech audio snippet. MLP classifiers are a good DNN model to start with because they are simple, flexible, and suited when inputs are assigned a label - in our case, emotion.
#
# I'm going to use the RAVDESS dataset (Ryerson Audio-Visual Database of Emotional Speech and Song dataset), created by Steven Livingstone and Frank Russo of Ryerson University. <br>
# [Details of the RAVDESS dataset](https://smartlaboratory.org/ravdess/) <br>
# [Download the dataset used in this notebook](https://zenodo.org/record/1188976) <br> Scroll half-way down the page and find "Audio_Speech_Actors_01-24"<br>
#
# We're going to use the audio-only speech portion of the RAVDESS dataset, ~200MB.
# Audio is sourced from 24 actors (12 male, 12 female) repeating two sentences with
# a variety of emotions and intensity. We get 1440 speech files (24 actors * 60 recordings per actor). Each audio sample has been rated  by a human 10 times for emotional quality.
#
# ## Machine Learning Process Overview
# 1. Feature Engineering: Choose and define the properties which our model will use to evaluate the audio files. <br>
# 2. Feature Extraction: Compute the features for each audio file and build a feature matrix representing all audio files. <br>
# 3. Model exploration: Test candidate models that make sense for the properies of the dataset
# 4. Training the MLP Classifier model: Choose and optimize the properties of our model on validation data - hyperparameters and architechture.  <br>
# 5. Evaluate our model's performance: Evaluate our model's accuracy on validation data and score it against test data which it has never seen in training.<br>
# 6. Explore options for improving our model: Is our dataset the right size? Is our model too complex or too simple? <br>

# %%
#importing the required libraries

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import librosa.display
import soundfile
import os
# matplotlib complains about the behaviour of librosa.display, so we'll ignore those warnings:
import warnings; warnings.filterwarnings('ignore')

# %% [markdown]
# ## Feature Extraction
# We're going to take full advantage of librosa, a Python library enabling audio analysis and feature extraction.
# Librosa abstracts away all the math and most of the details of mel spectrorgams, chromagrams, and MFCC.
# Although closely related, we're going to take the Mel Spectrogram, MFCC, and chromagrams of each audio file as separate features to try
# and have bit more discriminatory power between samples. <br>
#
# Let's build our feature extraction functions to get a chromagram, a mel spectorgram, and MFC coefficients for each of our audio files. Because the chromagram, mel spectrogram and MFCCs are calculated on audio frames produced by STFT, we're going to get a matrix back from each function, so we'll take the mean of those matrices to produce a single feature array for each feature and each audio sample, i.e. 3 feature arrays per audio sample.
#
# **Chromagram**: Will produce 12 features; One for each of 12 pitch classes
#
# **Mel Spectrogram**: Will produce 128 features; We've defined the number of mel frequency bands at n_mels=128
#
# **MFCC**: Will produce 40 MFCCs; I've set the number of coefficients to return at n_mfcc=40 which I found to work well

# %%
def feature_chromagram(waveform, sample_rate):
    # STFT computed here explicitly; mel spectrogram and MFCC functions do this under the hood
    stft_spectrogram=np.abs(librosa.stft(waveform))
    # Produce the chromagram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    chromagram=np.mean(librosa.feature.chroma_stft(S=stft_spectrogram, sr=sample_rate).T,axis=0)
    return chromagram

def feature_melspectrogram(waveform, sample_rate):
    # Produce the mel spectrogram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # Using 8khz as upper frequency bound should be enough for most speech classification tasks
    melspectrogram=np.mean(librosa.feature.melspectrogram(y=waveform, sr=sample_rate, n_mels=128, fmax=8000).T,axis=0)
    return melspectrogram

def feature_mfcc(waveform, sample_rate):
    # Compute the MFCCs for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    # 40 filterbanks = 40 coefficients
    mfc_coefficients=np.mean(librosa.feature.mfcc(y=waveform, sr=sample_rate, n_mfcc=40).T, axis=0)
    return mfc_coefficients

# %% [markdown]
# We're going to wrap our feature extraction functions so we only have to load each audio file once. After extracting our 3 audio features as NumPy arrays representing a time series, we're going to
# stack them horizontally to create a single feature array.

# %%
def get_features(file):
    # load an individual soundfile
     with soundfile.SoundFile(file) as audio:
        waveform = audio.read(dtype="float32")
        sample_rate = audio.samplerate
        # compute features of soundfile
        chromagram = feature_chromagram(waveform, sample_rate)
        melspectrogram = feature_melspectrogram(waveform, sample_rate)
        mfc_coefficients = feature_mfcc(waveform, sample_rate)

        feature_matrix=np.array([])
        # use np.hstack to stack our feature arrays horizontally to create a feature matrix
        feature_matrix = np.hstack((chromagram, melspectrogram, mfc_coefficients))

        return feature_matrix

# %% [markdown]
# ### Load the Dataset and Compute Features
# We have to understand the labelling of the RAVDESS dataset to find the ground truth emotion for each sample.
# Each file is labelled with 7 numbers delimited by a "-".
# Most of the numbers describe metadata about the audio samples such as their format (video and/or audio),
# whether the audio is a song or statement, which of two statements is being read and by which actor.
#
# The third and fourth numbers pertain to the emotional quality of each sample. The third number is in the range of 1-8 with each number representing an emotion.
# The fourth number is either 1 or 2, representing normal (1) or strong (2) emotional intensity.
#
# We're going to define a dictionary based on the third number (emotion) and assign an emotion to each number as specified by the RAVDESS dataset:

# %%
#Emotions in the RAVDESS dataset
emotions ={
  '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'
}

# %% [markdown]
# Finally, let's load our entire dataset and compute the features of each audio file:

# %%
import os, glob

def load_data():
    X,y=[],[]
    count = 0
    for file in glob.glob("/content/drive/MyDrive/ColabNotebooks/RAVDESS/audio_speech_actors_01-24/Actor_*/*.wav"):
        file_name=os.path.basename(file)
        emotion=emotions[file_name.split("-")[2]]
        features = get_features(file)
        X.append(features)
        y.append(emotion)
        count += 1
    # Since I didn't export the features in an excel sheet I am running it again here.
        print('\n' + f' Processed {count}/{1435} audio samples',end=' ')
    # Return arrays to plug into sklearn's cross-validation algorithms
    return np.array(X), np.array(y)

# %% [markdown]
# Compute the feature matrix and read the emotion labels for the entire dataset.
# Note that our regressor (independent/explanatory variable), usually denoted X, is named 'features', and our regressand (dependent variable), usually denoted y, is named 'emotions'.

# %%
features, emotions = load_data()
# Out:
#  Processed 1/1435 audio samples
#  Processed 2/1435 audio samples
#  Processed 3/1435 audio samples
#  Processed 4/1435 audio samples
#  Processed 5/1435 audio samples
#  Processed 6/1435 audio samples
#  Processed 7/1435 audio samples
#  Processed 8/1435 audio samples
#  Processed 9/1435 audio samples
#  Processed 10/1435 audio samples
#  Processed 11/1435 audio samples
#  Processed 12/1435 audio samples
#  Processed 13/1435 audio samples
#  Processed 14/1435 audio samples
#  Processed 15/1435 audio samples
#  Processed 16/1435 audio samples
#  Processed 17/1435 audio samples
#  Processed 18/1435 audio samples
#  Processed 19/1435 audio samples
#  Processed 20/1435 audio samples
#  Processed 21/1435 audio samples
#  Processed 22/1435 audio samples
#  Processed 23/1435 audio samples
#  Processed 24/1435 audio samples
#  Processed 25/1435 audio samples
#  Processed 26/1435 audio samples
#  Processed 27/1435 audio samples
#  Processed 28/1435 audio samples
#  Processed 29/1435 audio samples
#  Processed 30/1435 audio samples
#  Processed 31/1435 audio samples
#  Processed 32/1435 audio samples
#  Processed 33/1435 audio samples
#  Processed 34/1435 audio samples
#  Processed 35/1435 audio samples
#  Processed 36/1435 audio samples
#  Processed 37/1435 audio samples
#  Processed 38/1435 audio samples
#  Processed 39/1435 audio samples
#  Processed 40/1435 audio samples
#  Processed 41/1435 audio samples
#  Processed 42/1435 audio samples
#  Processed 43/1435 audio samples
#  Processed 44/1435 audio samples
#  Processed 45/1435 audio samples
#  Processed 46/1435 audio samples
#  Processed 47/1435 audio samples
#  Processed 48/1435 audio samples
#  Processed 49/1435 audio samples
#  Processed 50/1435 audio samples
#  Processed 51/1435 audio samples
#  Processed 52/1435 audio samples
#  Processed 53/1435 audio samples
#  Processed 54/1435 audio samples
#  Processed 55/1435 audio samples
#  Processed 56/1435 audio samples
#  Processed 57/1435 audio samples
#  Processed 58/1435 audio samples
#  Processed 59/1435 audio samples
#  Processed 60/1435 audio samples
#  Processed 61/1435 audio samples
#  Processed 62/1435 audio samples
#  Processed 63/1435 audio samples
#  Processed 64/1435 audio samples
#  Processed 65/1435 audio samples
#  Processed 66/1435 audio samples
#  Processed 67/1435 audio samples
#  Processed 68/1435 audio samples
#  Processed 69/1435 audio samples
#  Processed 70/1435 audio samples
#  Processed 71/1435 audio samples
#  Processed 72/1435 audio samples
#  Processed 73/1435 audio samples
#  Processed 74/1435 audio samples
#  Processed 75/1435 audio samples
#  Processed 76/1435 audio samples
#  Processed 77/1435 audio samples
#  Processed 78/1435 audio samples
#  Processed 79/1435 audio samples
#  Processed 80/1435 audio samples
#  Processed 81/1435 audio samples
#  Processed 82/1435 audio samples
#  Processed 83/1435 audio samples
#  Processed 84/1435 audio samples
#  Processed 85/1435 audio samples
#  Processed 86/1435 audio samples
#  Processed 87/1435 audio samples
#  Processed 88/1435 audio samples
#  Processed 89/1435 audio samples
#  Processed 90/1435 audio samples
#  Processed 91/1435 audio samples
#  Processed 92/1435 audio samples
#  Processed 93/1435 audio samples
#  Processed 94/1435 audio samples
#  Processed 95/1435 audio samples
#  Processed 96/1435 audio samples
#  Processed 97/1435 audio samples
#  Processed 98/1435 audio samples
#  Processed 99/1435 audio samples
#  Processed 100/1435 audio samples
#  Processed 101/1435 audio samples
#  Processed 102/1435 audio samples
#  Processed 103/1435 audio samples
#  Processed 104/1435 audio samples
#  Processed 105/1435 audio samples
#  Processed 106/1435 audio samples
#  Processed 107/1435 audio samples
#  Processed 108/1435 audio samples
#  Processed 109/1435 audio samples
#  Processed 110/1435 audio samples
#  Processed 111/1435 audio samples
#  Processed 112/1435 audio samples
#  Processed 113/1435 audio samples
#  Processed 114/1435 audio samples
#  Processed 115/1435 audio samples
#  Processed 116/1435 audio samples
#  Processed 117/1435 audio samples
#  Processed 118/1435 audio samples
#  Processed 119/1435 audio samples
#  Processed 120/1435 audio samples
#  Processed 121/1435 audio samples
#  Processed 122/1435 audio samples
#  Processed 123/1435 audio samples
#  Processed 124/1435 audio samples
#  Processed 125/1435 audio samples
#  Processed 126/1435 audio samples
#  Processed 127/1435 audio samples
#  Processed 128/1435 audio samples
#  Processed 129/1435 audio samples
#  Processed 130/1435 audio samples
#  Processed 131/1435 audio samples
#  Processed 132/1435 audio samples
#  Processed 133/1435 audio samples
#  Processed 134/1435 audio samples
#  Processed 135/1435 audio samples
#  Processed 136/1435 audio samples
#  Processed 137/1435 audio samples
#  Processed 138/1435 audio samples
#  Processed 139/1435 audio samples
#  Processed 140/1435 audio samples
#  Processed 141/1435 audio samples
#  Processed 142/1435 audio samples
#  Processed 143/1435 audio samples
#  Processed 144/1435 audio samples
#  Processed 145/1435 audio samples
#  Processed 146/1435 audio samples
#  Processed 147/1435 audio samples
#  Processed 148/1435 audio samples
#  Processed 149/1435 audio samples
#  Processed 150/1435 audio samples
#  Processed 151/1435 audio samples
#  Processed 152/1435 audio samples
#  Processed 153/1435 audio samples
#  Processed 154/1435 audio samples
#  Processed 155/1435 audio samples
#  Processed 156/1435 audio samples
#  Processed 157/1435 audio samples
#  Processed 158/1435 audio samples
#  Processed 159/1435 audio samples
#  Processed 160/1435 audio samples
#  Processed 161/1435 audio samples
#  Processed 162/1435 audio samples
#  Processed 163/1435 audio samples
#  Processed 164/1435 audio samples
#  Processed 165/1435 audio samples
#  Processed 166/1435 audio samples
#  Processed 167/1435 audio samples
#  Processed 168/1435 audio samples
#  Processed 169/1435 audio samples
#  Processed 170/1435 audio samples
#  Processed 171/1435 audio samples
#  Processed 172/1435 audio samples
#  Processed 173/1435 audio samples
#  Processed 174/1435 audio samples
#  Processed 175/1435 audio samples
#  Processed 176/1435 audio samples
#  Processed 177/1435 audio samples
#  Processed 178/1435 audio samples
#  Processed 179/1435 audio samples
#  Processed 180/1435 audio samples
#  Processed 181/1435 audio samples
#  Processed 182/1435 audio samples
#  Processed 183/1435 audio samples
#  Processed 184/1435 audio samples
#  Processed 185/1435 audio samples
#  Processed 186/1435 audio samples
#  Processed 187/1435 audio samples
#  Processed 188/1435 audio samples
#  Processed 189/1435 audio samples
#  Processed 190/1435 audio samples
#  Processed 191/1435 audio samples
#  Processed 192/1435 audio samples
#  Processed 193/1435 audio samples
#  Processed 194/1435 audio samples
#  Processed 195/1435 audio samples
#  Processed 196/1435 audio samples
#  Processed 197/1435 audio samples
#  Processed 198/1435 audio samples
#  Processed 199/1435 audio samples
#  Processed 200/1435 audio samples
#  Processed 201/1435 audio samples
#  Processed 202/1435 audio samples
#  Processed 203/1435 audio samples
#  Processed 204/1435 audio samples
#  Processed 205/1435 audio samples
#  Processed 206/1435 audio samples
#  Processed 207/1435 audio samples
#  Processed 208/1435 audio samples
#  Processed 209/1435 audio samples
#  Processed 210/1435 audio samples
#  Processed 211/1435 audio samples
#  Processed 212/1435 audio samples
#  Processed 213/1435 audio samples
#  Processed 214/1435 audio samples
#  Processed 215/1435 audio samples
#  Processed 216/1435 audio samples
#  Processed 217/1435 audio samples
#  Processed 218/1435 audio samples
#  Processed 219/1435 audio samples
#  Processed 220/1435 audio samples
#  Processed 221/1435 audio samples
#  Processed 222/1435 audio samples
#  Processed 223/1435 audio samples
#  Processed 224/1435 audio samples
#  Processed 225/1435 audio samples
#  Processed 226/1435 audio samples
#  Processed 227/1435 audio samples
#  Processed 228/1435 audio samples
#  Processed 229/1435 audio samples
#  Processed 230/1435 audio samples
#  Processed 231/1435 audio samples
#  Processed 232/1435 audio samples
#  Processed 233/1435 audio samples
#  Processed 234/1435 audio samples
#  Processed 235/1435 audio samples
#  Processed 236/1435 audio samples
#  Processed 237/1435 audio samples
#  Processed 238/1435 audio samples
#  Processed 239/1435 audio samples
#  Processed 240/1435 audio samples
#  Processed 241/1435 audio samples
#  Processed 242/1435 audio samples
#  Processed 243/1435 audio samples
#  Processed 244/1435 audio samples
#  Processed 245/1435 audio samples
#  Processed 246/1435 audio samples
#  Processed 247/1435 audio samples
#  Processed 248/1435 audio samples
#  Processed 249/1435 audio samples
#  Processed 250/1435 audio samples
#  Processed 251/1435 audio samples
#  Processed 252/1435 audio samples
#  Processed 253/1435 audio samples
#  Processed 254/1435 audio samples
#  Processed 255/1435 audio samples
#  Processed 256/1435 audio samples
#  Processed 257/1435 audio samples
#  Processed 258/1435 audio samples
#  Processed 259/1435 audio samples
#  Processed 260/1435 audio samples
#  Processed 261/1435 audio samples
#  Processed 262/1435 audio samples
#  Processed 263/1435 audio samples
#  Processed 264/1435 audio samples
#  Processed 265/1435 audio samples
#  Processed 266/1435 audio samples
#  Processed 267/1435 audio samples
#  Processed 268/1435 audio samples
#  Processed 269/1435 audio samples
#  Processed 270/1435 audio samples
#  Processed 271/1435 audio samples
#  Processed 272/1435 audio samples
#  Processed 273/1435 audio samples
#  Processed 274/1435 audio samples
#  Processed 275/1435 audio samples
#  Processed 276/1435 audio samples
#  Processed 277/1435 audio samples
#  Processed 278/1435 audio samples
#  Processed 279/1435 audio samples
#  Processed 280/1435 audio samples
#  Processed 281/1435 audio samples
#  Processed 282/1435 audio samples
#  Processed 283/1435 audio samples
#  Processed 284/1435 audio samples
#  Processed 285/1435 audio samples
#  Processed 286/1435 audio samples
#  Processed 287/1435 audio samples
#  Processed 288/1435 audio samples
#  Processed 289/1435 audio samples
#  Processed 290/1435 audio samples
#  Processed 291/1435 audio samples
#  Processed 292/1435 audio samples
#  Processed 293/1435 audio samples
#  Processed 294/1435 audio samples
#  Processed 295/1435 audio samples
#  Processed 296/1435 audio samples
#  Processed 297/1435 audio samples
#  Processed 298/1435 audio samples
#  Processed 299/1435 audio samples
#  Processed 300/1435 audio samples
#  Processed 301/1435 audio samples
#  Processed 302/1435 audio samples
#  Processed 303/1435 audio samples
#  Processed 304/1435 audio samples
#  Processed 305/1435 audio samples
#  Processed 306/1435 audio samples
#  Processed 307/1435 audio samples
#  Processed 308/1435 audio samples
#  Processed 309/1435 audio samples
#  Processed 310/1435 audio samples
#  Processed 311/1435 audio samples
#  Processed 312/1435 audio samples
#  Processed 313/1435 audio samples
#  Processed 314/1435 audio samples
#  Processed 315/1435 audio samples
#  Processed 316/1435 audio samples
#  Processed 317/1435 audio samples
#  Processed 318/1435 audio samples
#  Processed 319/1435 audio samples
#  Processed 320/1435 audio samples
#  Processed 321/1435 audio samples
#  Processed 322/1435 audio samples
#  Processed 323/1435 audio samples
#  Processed 324/1435 audio samples
#  Processed 325/1435 audio samples
#  Processed 326/1435 audio samples
#  Processed 327/1435 audio samples
#  Processed 328/1435 audio samples
#  Processed 329/1435 audio samples
#  Processed 330/1435 audio samples
#  Processed 331/1435 audio samples
#  Processed 332/1435 audio samples
#  Processed 333/1435 audio samples
#  Processed 334/1435 audio samples
#  Processed 335/1435 audio samples
#  Processed 336/1435 audio samples
#  Processed 337/1435 audio samples
#  Processed 338/1435 audio samples
#  Processed 339/1435 audio samples
#  Processed 340/1435 audio samples
#  Processed 341/1435 audio samples
#  Processed 342/1435 audio samples
#  Processed 343/1435 audio samples
#  Processed 344/1435 audio samples
#  Processed 345/1435 audio samples
#  Processed 346/1435 audio samples
#  Processed 347/1435 audio samples
#  Processed 348/1435 audio samples
#  Processed 349/1435 audio samples
#  Processed 350/1435 audio samples
#  Processed 351/1435 audio samples
#  Processed 352/1435 audio samples
#  Processed 353/1435 audio samples
#  Processed 354/1435 audio samples
#  Processed 355/1435 audio samples
#  Processed 356/1435 audio samples
#  Processed 357/1435 audio samples
#  Processed 358/1435 audio samples
#  Processed 359/1435 audio samples
#  Processed 360/1435 audio samples
#  Processed 361/1435 audio samples
#  Processed 362/1435 audio samples
#  Processed 363/1435 audio samples
#  Processed 364/1435 audio samples
#  Processed 365/1435 audio samples
#  Processed 366/1435 audio samples
#  Processed 367/1435 audio samples
#  Processed 368/1435 audio samples
#  Processed 369/1435 audio samples
#  Processed 370/1435 audio samples
#  Processed 371/1435 audio samples
#  Processed 372/1435 audio samples
#  Processed 373/1435 audio samples
#  Processed 374/1435 audio samples
#  Processed 375/1435 audio samples
#  Processed 376/1435 audio samples
#  Processed 377/1435 audio samples
#  Processed 378/1435 audio samples
#  Processed 379/1435 audio samples
#  Processed 380/1435 audio samples
#  Processed 381/1435 audio samples
#  Processed 382/1435 audio samples
#  Processed 383/1435 audio samples
#  Processed 384/1435 audio samples
#  Processed 385/1435 audio samples
#  Processed 386/1435 audio samples
#  Processed 387/1435 audio samples
#  Processed 388/1435 audio samples
#  Processed 389/1435 audio samples
#  Processed 390/1435 audio samples
#  Processed 391/1435 audio samples
#  Processed 392/1435 audio samples
#  Processed 393/1435 audio samples
#  Processed 394/1435 audio samples
#  Processed 395/1435 audio samples
#  Processed 396/1435 audio samples
#  Processed 397/1435 audio samples
#  Processed 398/1435 audio samples
#  Processed 399/1435 audio samples
#  Processed 400/1435 audio samples
#  Processed 401/1435 audio samples
#  Processed 402/1435 audio samples
#  Processed 403/1435 audio samples
#  Processed 404/1435 audio samples
#  Processed 405/1435 audio samples
#  Processed 406/1435 audio samples
#  Processed 407/1435 audio samples
#  Processed 408/1435 audio samples
#  Processed 409/1435 audio samples
#  Processed 410/1435 audio samples
#  Processed 411/1435 audio samples
#  Processed 412/1435 audio samples
#  Processed 413/1435 audio samples
#  Processed 414/1435 audio samples
#  Processed 415/1435 audio samples
#  Processed 416/1435 audio samples
#  Processed 417/1435 audio samples
#  Processed 418/1435 audio samples
#  Processed 419/1435 audio samples
#  Processed 420/1435 audio samples
#  Processed 421/1435 audio samples
#  Processed 422/1435 audio samples
#  Processed 423/1435 audio samples
#  Processed 424/1435 audio samples
#  Processed 425/1435 audio samples
#  Processed 426/1435 audio samples
#  Processed 427/1435 audio samples
#  Processed 428/1435 audio samples
#  Processed 429/1435 audio samples
#  Processed 430/1435 audio samples
#  Processed 431/1435 audio samples
#  Processed 432/1435 audio samples
#  Processed 433/1435 audio samples
#  Processed 434/1435 audio samples
#  Processed 435/1435 audio samples
#  Processed 436/1435 audio samples
#  Processed 437/1435 audio samples
#  Processed 438/1435 audio samples
#  Processed 439/1435 audio samples
#  Processed 440/1435 audio samples
#  Processed 441/1435 audio samples
#  Processed 442/1435 audio samples
#  Processed 443/1435 audio samples
#  Processed 444/1435 audio samples
#  Processed 445/1435 audio samples
#  Processed 446/1435 audio samples
#  Processed 447/1435 audio samples
#  Processed 448/1435 audio samples
#  Processed 449/1435 audio samples
#  Processed 450/1435 audio samples
#  Processed 451/1435 audio samples
#  Processed 452/1435 audio samples
#  Processed 453/1435 audio samples
#  Processed 454/1435 audio samples
#  Processed 455/1435 audio samples
#  Processed 456/1435 audio samples
#  Processed 457/1435 audio samples
#  Processed 458/1435 audio samples
#  Processed 459/1435 audio samples
#  Processed 460/1435 audio samples
#  Processed 461/1435 audio samples
#  Processed 462/1435 audio samples
#  Processed 463/1435 audio samples
#  Processed 464/1435 audio samples
#  Processed 465/1435 audio samples
#  Processed 466/1435 audio samples
#  Processed 467/1435 audio samples
#  Processed 468/1435 audio samples
#  Processed 469/1435 audio samples
#  Processed 470/1435 audio samples
#  Processed 471/1435 audio samples
#  Processed 472/1435 audio samples
#  Processed 473/1435 audio samples
#  Processed 474/1435 audio samples
#  Processed 475/1435 audio samples
#  Processed 476/1435 audio samples
#  Processed 477/1435 audio samples
#  Processed 478/1435 audio samples
#  Processed 479/1435 audio samples
#  Processed 480/1435 audio samples
#  Processed 481/1435 audio samples
#  Processed 482/1435 audio samples
#  Processed 483/1435 audio samples
#  Processed 484/1435 audio samples
#  Processed 485/1435 audio samples
#  Processed 486/1435 audio samples
#  Processed 487/1435 audio samples
#  Processed 488/1435 audio samples
#  Processed 489/1435 audio samples
#  Processed 490/1435 audio samples
#  Processed 491/1435 audio samples
#  Processed 492/1435 audio samples
#  Processed 493/1435 audio samples
#  Processed 494/1435 audio samples
#  Processed 495/1435 audio samples
#  Processed 496/1435 audio samples
#  Processed 497/1435 audio samples
#  Processed 498/1435 audio samples
#  Processed 499/1435 audio samples
#  Processed 500/1435 audio samples
#  Processed 501/1435 audio samples
#  Processed 502/1435 audio samples
#  Processed 503/1435 audio samples
#  Processed 504/1435 audio samples
#  Processed 505/1435 audio samples
#  Processed 506/1435 audio samples
#  Processed 507/1435 audio samples
#  Processed 508/1435 audio samples
#  Processed 509/1435 audio samples
#  Processed 510/1435 audio samples
#  Processed 511/1435 audio samples
#  Processed 512/1435 audio samples
#  Processed 513/1435 audio samples
#  Processed 514/1435 audio samples
#  Processed 515/1435 audio samples
#  Processed 516/1435 audio samples
#  Processed 517/1435 audio samples
#  Processed 518/1435 audio samples
#  Processed 519/1435 audio samples
#  Processed 520/1435 audio samples
#  Processed 521/1435 audio samples
#  Processed 522/1435 audio samples
#  Processed 523/1435 audio samples
#  Processed 524/1435 audio samples
#  Processed 525/1435 audio samples
#  Processed 526/1435 audio samples
#  Processed 527/1435 audio samples
#  Processed 528/1435 audio samples
#  Processed 529/1435 audio samples
#  Processed 530/1435 audio samples
#  Processed 531/1435 audio samples
#  Processed 532/1435 audio samples
#  Processed 533/1435 audio samples
#  Processed 534/1435 audio samples
#  Processed 535/1435 audio samples
#  Processed 536/1435 audio samples
#  Processed 537/1435 audio samples
#  Processed 538/1435 audio samples
#  Processed 539/1435 audio samples
#  Processed 540/1435 audio samples
#  Processed 541/1435 audio samples
#  Processed 542/1435 audio samples
#  Processed 543/1435 audio samples
#  Processed 544/1435 audio samples
#  Processed 545/1435 audio samples
#  Processed 546/1435 audio samples
#  Processed 547/1435 audio samples
#  Processed 548/1435 audio samples
#  Processed 549/1435 audio samples
#  Processed 550/1435 audio samples
#  Processed 551/1435 audio samples
#  Processed 552/1435 audio samples
#  Processed 553/1435 audio samples
#  Processed 554/1435 audio samples
#  Processed 555/1435 audio samples
#  Processed 556/1435 audio samples
#  Processed 557/1435 audio samples
#  Processed 558/1435 audio samples
#  Processed 559/1435 audio samples
#  Processed 560/1435 audio samples
#  Processed 561/1435 audio samples
#  Processed 562/1435 audio samples
#  Processed 563/1435 audio samples
#  Processed 564/1435 audio samples
#  Processed 565/1435 audio samples
#  Processed 566/1435 audio samples
#  Processed 567/1435 audio samples
#  Processed 568/1435 audio samples
#  Processed 569/1435 audio samples
#  Processed 570/1435 audio samples
#  Processed 571/1435 audio samples
#  Processed 572/1435 audio samples
#  Processed 573/1435 audio samples
#  Processed 574/1435 audio samples
#  Processed 575/1435 audio samples
#  Processed 576/1435 audio samples
#  Processed 577/1435 audio samples
#  Processed 578/1435 audio samples
#  Processed 579/1435 audio samples
#  Processed 580/1435 audio samples
#  Processed 581/1435 audio samples
#  Processed 582/1435 audio samples
#  Processed 583/1435 audio samples
#  Processed 584/1435 audio samples
#  Processed 585/1435 audio samples
#  Processed 586/1435 audio samples
#  Processed 587/1435 audio samples
#  Processed 588/1435 audio samples
#  Processed 589/1435 audio samples
#  Processed 590/1435 audio samples
#  Processed 591/1435 audio samples
#  Processed 592/1435 audio samples
#  Processed 593/1435 audio samples
#  Processed 594/1435 audio samples
#  Processed 595/1435 audio samples
#  Processed 596/1435 audio samples
#  Processed 597/1435 audio samples
#  Processed 598/1435 audio samples
#  Processed 599/1435 audio samples
#  Processed 600/1435 audio samples
#  Processed 601/1435 audio samples
#  Processed 602/1435 audio samples
#  Processed 603/1435 audio samples
#  Processed 604/1435 audio samples
#  Processed 605/1435 audio samples
#  Processed 606/1435 audio samples
#  Processed 607/1435 audio samples
#  Processed 608/1435 audio samples
#  Processed 609/1435 audio samples
#  Processed 610/1435 audio samples
#  Processed 611/1435 audio samples
#  Processed 612/1435 audio samples
#  Processed 613/1435 audio samples
#  Processed 614/1435 audio samples
#  Processed 615/1435 audio samples
#  Processed 616/1435 audio samples
#  Processed 617/1435 audio samples
#  Processed 618/1435 audio samples
#  Processed 619/1435 audio samples
#  Processed 620/1435 audio samples
#  Processed 621/1435 audio samples
#  Processed 622/1435 audio samples
#  Processed 623/1435 audio samples
#  Processed 624/1435 audio samples
#  Processed 625/1435 audio samples
#  Processed 626/1435 audio samples
#  Processed 627/1435 audio samples
#  Processed 628/1435 audio samples
#  Processed 629/1435 audio samples
#  Processed 630/1435 audio samples
#  Processed 631/1435 audio samples
#  Processed 632/1435 audio samples
#  Processed 633/1435 audio samples
#  Processed 634/1435 audio samples
#  Processed 635/1435 audio samples
#  Processed 636/1435 audio samples
#  Processed 637/1435 audio samples
#  Processed 638/1435 audio samples
#  Processed 639/1435 audio samples
#  Processed 640/1435 audio samples
#  Processed 641/1435 audio samples
#  Processed 642/1435 audio samples
#  Processed 643/1435 audio samples
#  Processed 644/1435 audio samples
#  Processed 645/1435 audio samples
#  Processed 646/1435 audio samples
#  Processed 647/1435 audio samples
#  Processed 648/1435 audio samples
#  Processed 649/1435 audio samples
#  Processed 650/1435 audio samples
#  Processed 651/1435 audio samples
#  Processed 652/1435 audio samples
#  Processed 653/1435 audio samples
#  Processed 654/1435 audio samples
#  Processed 655/1435 audio samples
#  Processed 656/1435 audio samples
#  Processed 657/1435 audio samples
#  Processed 658/1435 audio samples
#  Processed 659/1435 audio samples
#  Processed 660/1435 audio samples
#  Processed 661/1435 audio samples
#  Processed 662/1435 audio samples
#  Processed 663/1435 audio samples
#  Processed 664/1435 audio samples
#  Processed 665/1435 audio samples
#  Processed 666/1435 audio samples
#  Processed 667/1435 audio samples
#  Processed 668/1435 audio samples
#  Processed 669/1435 audio samples
#  Processed 670/1435 audio samples
#  Processed 671/1435 audio samples
#  Processed 672/1435 audio samples
#  Processed 673/1435 audio samples
#  Processed 674/1435 audio samples
#  Processed 675/1435 audio samples
#  Processed 676/1435 audio samples
#  Processed 677/1435 audio samples
#  Processed 678/1435 audio samples
#  Processed 679/1435 audio samples
#  Processed 680/1435 audio samples
#  Processed 681/1435 audio samples
#  Processed 682/1435 audio samples
#  Processed 683/1435 audio samples
#  Processed 684/1435 audio samples
#  Processed 685/1435 audio samples
#  Processed 686/1435 audio samples
#  Processed 687/1435 audio samples
#  Processed 688/1435 audio samples
#  Processed 689/1435 audio samples
#  Processed 690/1435 audio samples
#  Processed 691/1435 audio samples
#  Processed 692/1435 audio samples
#  Processed 693/1435 audio samples
#  Processed 694/1435 audio samples
#  Processed 695/1435 audio samples
#  Processed 696/1435 audio samples
#  Processed 697/1435 audio samples
#  Processed 698/1435 audio samples
#  Processed 699/1435 audio samples
#  Processed 700/1435 audio samples
#  Processed 701/1435 audio samples
#  Processed 702/1435 audio samples
#  Processed 703/1435 audio samples
#  Processed 704/1435 audio samples
#  Processed 705/1435 audio samples
#  Processed 706/1435 audio samples
#  Processed 707/1435 audio samples
#  Processed 708/1435 audio samples
#  Processed 709/1435 audio samples
#  Processed 710/1435 audio samples
#  Processed 711/1435 audio samples
#  Processed 712/1435 audio samples
#  Processed 713/1435 audio samples
#  Processed 714/1435 audio samples
#  Processed 715/1435 audio samples
#  Processed 716/1435 audio samples
#  Processed 717/1435 audio samples
#  Processed 718/1435 audio samples
#  Processed 719/1435 audio samples
#  Processed 720/1435 audio samples
#  Processed 721/1435 audio samples
#  Processed 722/1435 audio samples
#  Processed 723/1435 audio samples
#  Processed 724/1435 audio samples
#  Processed 725/1435 audio samples
#  Processed 726/1435 audio samples
#  Processed 727/1435 audio samples
#  Processed 728/1435 audio samples
#  Processed 729/1435 audio samples
#  Processed 730/1435 audio samples
#  Processed 731/1435 audio samples
#  Processed 732/1435 audio samples
#  Processed 733/1435 audio samples
#  Processed 734/1435 audio samples
#  Processed 735/1435 audio samples
#  Processed 736/1435 audio samples
#  Processed 737/1435 audio samples
#  Processed 738/1435 audio samples
#  Processed 739/1435 audio samples
#  Processed 740/1435 audio samples
#  Processed 741/1435 audio samples
#  Processed 742/1435 audio samples
#  Processed 743/1435 audio samples
#  Processed 744/1435 audio samples
#  Processed 745/1435 audio samples
#  Processed 746/1435 audio samples
#  Processed 747/1435 audio samples
#  Processed 748/1435 audio samples
#  Processed 749/1435 audio samples
#  Processed 750/1435 audio samples
#  Processed 751/1435 audio samples
#  Processed 752/1435 audio samples
#  Processed 753/1435 audio samples
#  Processed 754/1435 audio samples
#  Processed 755/1435 audio samples
#  Processed 756/1435 audio samples
#  Processed 757/1435 audio samples
#  Processed 758/1435 audio samples
#  Processed 759/1435 audio samples
#  Processed 760/1435 audio samples
#  Processed 761/1435 audio samples
#  Processed 762/1435 audio samples
#  Processed 763/1435 audio samples
#  Processed 764/1435 audio samples
#  Processed 765/1435 audio samples
#  Processed 766/1435 audio samples
#  Processed 767/1435 audio samples
#  Processed 768/1435 audio samples
#  Processed 769/1435 audio samples
#  Processed 770/1435 audio samples
#  Processed 771/1435 audio samples
#  Processed 772/1435 audio samples
#  Processed 773/1435 audio samples
#  Processed 774/1435 audio samples
#  Processed 775/1435 audio samples
#  Processed 776/1435 audio samples
#  Processed 777/1435 audio samples
#  Processed 778/1435 audio samples
#  Processed 779/1435 audio samples
#  Processed 780/1435 audio samples
#  Processed 781/1435 audio samples
#  Processed 782/1435 audio samples
#  Processed 783/1435 audio samples
#  Processed 784/1435 audio samples
#  Processed 785/1435 audio samples
#  Processed 786/1435 audio samples
#  Processed 787/1435 audio samples
#  Processed 788/1435 audio samples
#  Processed 789/1435 audio samples
#  Processed 790/1435 audio samples
#  Processed 791/1435 audio samples
#  Processed 792/1435 audio samples
#  Processed 793/1435 audio samples
#  Processed 794/1435 audio samples
#  Processed 795/1435 audio samples
#  Processed 796/1435 audio samples
#  Processed 797/1435 audio samples
#  Processed 798/1435 audio samples
#  Processed 799/1435 audio samples
#  Processed 800/1435 audio samples
#  Processed 801/1435 audio samples
#  Processed 802/1435 audio samples
#  Processed 803/1435 audio samples
#  Processed 804/1435 audio samples
#  Processed 805/1435 audio samples
#  Processed 806/1435 audio samples
#  Processed 807/1435 audio samples
#  Processed 808/1435 audio samples
#  Processed 809/1435 audio samples
#  Processed 810/1435 audio samples
#  Processed 811/1435 audio samples
#  Processed 812/1435 audio samples
#  Processed 813/1435 audio samples
#  Processed 814/1435 audio samples
#  Processed 815/1435 audio samples
#  Processed 816/1435 audio samples
#  Processed 817/1435 audio samples
#  Processed 818/1435 audio samples
#  Processed 819/1435 audio samples
#  Processed 820/1435 audio samples
#  Processed 821/1435 audio samples
#  Processed 822/1435 audio samples
#  Processed 823/1435 audio samples
#  Processed 824/1435 audio samples
#  Processed 825/1435 audio samples
#  Processed 826/1435 audio samples
#  Processed 827/1435 audio samples
#  Processed 828/1435 audio samples
#  Processed 829/1435 audio samples
#  Processed 830/1435 audio samples
#  Processed 831/1435 audio samples
#  Processed 832/1435 audio samples
#  Processed 833/1435 audio samples
#  Processed 834/1435 audio samples
#  Processed 835/1435 audio samples
#  Processed 836/1435 audio samples
#  Processed 837/1435 audio samples
#  Processed 838/1435 audio samples
#  Processed 839/1435 audio samples
#  Processed 840/1435 audio samples
#  Processed 841/1435 audio samples
#  Processed 842/1435 audio samples
#  Processed 843/1435 audio samples
#  Processed 844/1435 audio samples
#  Processed 845/1435 audio samples
#  Processed 846/1435 audio samples
#  Processed 847/1435 audio samples
#  Processed 848/1435 audio samples
#  Processed 849/1435 audio samples
#  Processed 850/1435 audio samples
#  Processed 851/1435 audio samples
#  Processed 852/1435 audio samples
#  Processed 853/1435 audio samples
#  Processed 854/1435 audio samples
#  Processed 855/1435 audio samples
#  Processed 856/1435 audio samples
#  Processed 857/1435 audio samples
#  Processed 858/1435 audio samples
#  Processed 859/1435 audio samples
#  Processed 860/1435 audio samples
#  Processed 861/1435 audio samples
#  Processed 862/1435 audio samples
#  Processed 863/1435 audio samples
#  Processed 864/1435 audio samples
#  Processed 865/1435 audio samples
#  Processed 866/1435 audio samples
#  Processed 867/1435 audio samples
#  Processed 868/1435 audio samples
#  Processed 869/1435 audio samples
#  Processed 870/1435 audio samples
#  Processed 871/1435 audio samples
#  Processed 872/1435 audio samples
#  Processed 873/1435 audio samples
#  Processed 874/1435 audio samples
#  Processed 875/1435 audio samples
#  Processed 876/1435 audio samples
#  Processed 877/1435 audio samples
#  Processed 878/1435 audio samples
#  Processed 879/1435 audio samples
#  Processed 880/1435 audio samples
#  Processed 881/1435 audio samples
#  Processed 882/1435 audio samples
#  Processed 883/1435 audio samples
#  Processed 884/1435 audio samples
#  Processed 885/1435 audio samples
#  Processed 886/1435 audio samples
#  Processed 887/1435 audio samples
#  Processed 888/1435 audio samples
#  Processed 889/1435 audio samples
#  Processed 890/1435 audio samples
#  Processed 891/1435 audio samples
#  Processed 892/1435 audio samples
#  Processed 893/1435 audio samples
#  Processed 894/1435 audio samples
#  Processed 895/1435 audio samples
#  Processed 896/1435 audio samples
#  Processed 897/1435 audio samples
#  Processed 898/1435 audio samples
#  Processed 899/1435 audio samples
#  Processed 900/1435 audio samples
#  Processed 901/1435 audio samples
#  Processed 902/1435 audio samples
#  Processed 903/1435 audio samples
#  Processed 904/1435 audio samples
#  Processed 905/1435 audio samples
#  Processed 906/1435 audio samples
#  Processed 907/1435 audio samples
#  Processed 908/1435 audio samples
#  Processed 909/1435 audio samples
#  Processed 910/1435 audio samples
#  Processed 911/1435 audio samples
#  Processed 912/1435 audio samples
#  Processed 913/1435 audio samples
#  Processed 914/1435 audio samples
#  Processed 915/1435 audio samples
#  Processed 916/1435 audio samples
#  Processed 917/1435 audio samples
#  Processed 918/1435 audio samples
#  Processed 919/1435 audio samples
#  Processed 920/1435 audio samples
#  Processed 921/1435 audio samples
#  Processed 922/1435 audio samples
#  Processed 923/1435 audio samples
#  Processed 924/1435 audio samples
#  Processed 925/1435 audio samples
#  Processed 926/1435 audio samples
#  Processed 927/1435 audio samples
#  Processed 928/1435 audio samples
#  Processed 929/1435 audio samples
#  Processed 930/1435 audio samples
#  Processed 931/1435 audio samples
#  Processed 932/1435 audio samples
#  Processed 933/1435 audio samples
#  Processed 934/1435 audio samples
#  Processed 935/1435 audio samples
#  Processed 936/1435 audio samples
#  Processed 937/1435 audio samples
#  Processed 938/1435 audio samples
#  Processed 939/1435 audio samples
#  Processed 940/1435 audio samples
#  Processed 941/1435 audio samples
#  Processed 942/1435 audio samples
#  Processed 943/1435 audio samples
#  Processed 944/1435 audio samples
#  Processed 945/1435 audio samples
#  Processed 946/1435 audio samples
#  Processed 947/1435 audio samples
#  Processed 948/1435 audio samples
#  Processed 949/1435 audio samples
#  Processed 950/1435 audio samples
#  Processed 951/1435 audio samples
#  Processed 952/1435 audio samples
#  Processed 953/1435 audio samples
#  Processed 954/1435 audio samples
#  Processed 955/1435 audio samples
#  Processed 956/1435 audio samples
#  Processed 957/1435 audio samples
#  Processed 958/1435 audio samples
#  Processed 959/1435 audio samples
#  Processed 960/1435 audio samples
#  Processed 961/1435 audio samples
#  Processed 962/1435 audio samples
#  Processed 963/1435 audio samples
#  Processed 964/1435 audio samples
#  Processed 965/1435 audio samples
#  Processed 966/1435 audio samples
#  Processed 967/1435 audio samples
#  Processed 968/1435 audio samples
#  Processed 969/1435 audio samples
#  Processed 970/1435 audio samples
#  Processed 971/1435 audio samples
#  Processed 972/1435 audio samples
#  Processed 973/1435 audio samples
#  Processed 974/1435 audio samples
#  Processed 975/1435 audio samples
#  Processed 976/1435 audio samples
#  Processed 977/1435 audio samples
#  Processed 978/1435 audio samples
#  Processed 979/1435 audio samples
#  Processed 980/1435 audio samples
#  Processed 981/1435 audio samples
#  Processed 982/1435 audio samples
#  Processed 983/1435 audio samples
#  Processed 984/1435 audio samples
#  Processed 985/1435 audio samples
#  Processed 986/1435 audio samples
#  Processed 987/1435 audio samples
#  Processed 988/1435 audio samples
#  Processed 989/1435 audio samples
#  Processed 990/1435 audio samples
#  Processed 991/1435 audio samples
#  Processed 992/1435 audio samples
#  Processed 993/1435 audio samples
#  Processed 994/1435 audio samples
#  Processed 995/1435 audio samples
#  Processed 996/1435 audio samples
#  Processed 997/1435 audio samples
#  Processed 998/1435 audio samples
#  Processed 999/1435 audio samples
#  Processed 1000/1435 audio samples
#  Processed 1001/1435 audio samples
#  Processed 1002/1435 audio samples
#  Processed 1003/1435 audio samples
#  Processed 1004/1435 audio samples
#  Processed 1005/1435 audio samples
#  Processed 1006/1435 audio samples
#  Processed 1007/1435 audio samples
#  Processed 1008/1435 audio samples
#  Processed 1009/1435 audio samples
#  Processed 1010/1435 audio samples
#  Processed 1011/1435 audio samples
#  Processed 1012/1435 audio samples
#  Processed 1013/1435 audio samples
#  Processed 1014/1435 audio samples
#  Processed 1015/1435 audio samples
#  Processed 1016/1435 audio samples
#  Processed 1017/1435 audio samples
#  Processed 1018/1435 audio samples
#  Processed 1019/1435 audio samples
#  Processed 1020/1435 audio samples
#  Processed 1021/1435 audio samples
#  Processed 1022/1435 audio samples
#  Processed 1023/1435 audio samples
#  Processed 1024/1435 audio samples
#  Processed 1025/1435 audio samples
#  Processed 1026/1435 audio samples
#  Processed 1027/1435 audio samples
#  Processed 1028/1435 audio samples
#  Processed 1029/1435 audio samples
#  Processed 1030/1435 audio samples
#  Processed 1031/1435 audio samples
#  Processed 1032/1435 audio samples
#  Processed 1033/1435 audio samples
#  Processed 1034/1435 audio samples
#  Processed 1035/1435 audio samples
#  Processed 1036/1435 audio samples
#  Processed 1037/1435 audio samples
#  Processed 1038/1435 audio samples
#  Processed 1039/1435 audio samples
#  Processed 1040/1435 audio samples
#  Processed 1041/1435 audio samples
#  Processed 1042/1435 audio samples
#  Processed 1043/1435 audio samples
#  Processed 1044/1435 audio samples
#  Processed 1045/1435 audio samples
#  Processed 1046/1435 audio samples
#  Processed 1047/1435 audio samples
#  Processed 1048/1435 audio samples
#  Processed 1049/1435 audio samples
#  Processed 1050/1435 audio samples
#  Processed 1051/1435 audio samples
#  Processed 1052/1435 audio samples
#  Processed 1053/1435 audio samples
#  Processed 1054/1435 audio samples
#  Processed 1055/1435 audio samples
#  Processed 1056/1435 audio samples
#  Processed 1057/1435 audio samples
#  Processed 1058/1435 audio samples
#  Processed 1059/1435 audio samples
#  Processed 1060/1435 audio samples
#  Processed 1061/1435 audio samples
#  Processed 1062/1435 audio samples
#  Processed 1063/1435 audio samples
#  Processed 1064/1435 audio samples
#  Processed 1065/1435 audio samples
#  Processed 1066/1435 audio samples
#  Processed 1067/1435 audio samples
#  Processed 1068/1435 audio samples
#  Processed 1069/1435 audio samples
#  Processed 1070/1435 audio samples
#  Processed 1071/1435 audio samples
#  Processed 1072/1435 audio samples
#  Processed 1073/1435 audio samples
#  Processed 1074/1435 audio samples
#  Processed 1075/1435 audio samples
#  Processed 1076/1435 audio samples
#  Processed 1077/1435 audio samples
#  Processed 1078/1435 audio samples
#  Processed 1079/1435 audio samples
#  Processed 1080/1435 audio samples
#  Processed 1081/1435 audio samples
#  Processed 1082/1435 audio samples
#  Processed 1083/1435 audio samples
#  Processed 1084/1435 audio samples
#  Processed 1085/1435 audio samples
#  Processed 1086/1435 audio samples
#  Processed 1087/1435 audio samples
#  Processed 1088/1435 audio samples
#  Processed 1089/1435 audio samples
#  Processed 1090/1435 audio samples
#  Processed 1091/1435 audio samples
#  Processed 1092/1435 audio samples
#  Processed 1093/1435 audio samples
#  Processed 1094/1435 audio samples
#  Processed 1095/1435 audio samples
#  Processed 1096/1435 audio samples
#  Processed 1097/1435 audio samples
#  Processed 1098/1435 audio samples
#  Processed 1099/1435 audio samples
#  Processed 1100/1435 audio samples
#  Processed 1101/1435 audio samples
#  Processed 1102/1435 audio samples
#  Processed 1103/1435 audio samples
#  Processed 1104/1435 audio samples
#  Processed 1105/1435 audio samples
#  Processed 1106/1435 audio samples
#  Processed 1107/1435 audio samples
#  Processed 1108/1435 audio samples
#  Processed 1109/1435 audio samples
#  Processed 1110/1435 audio samples
#  Processed 1111/1435 audio samples
#  Processed 1112/1435 audio samples
#  Processed 1113/1435 audio samples
#  Processed 1114/1435 audio samples
#  Processed 1115/1435 audio samples
#  Processed 1116/1435 audio samples
#  Processed 1117/1435 audio samples
#  Processed 1118/1435 audio samples
#  Processed 1119/1435 audio samples
#  Processed 1120/1435 audio samples
#  Processed 1121/1435 audio samples
#  Processed 1122/1435 audio samples
#  Processed 1123/1435 audio samples
#  Processed 1124/1435 audio samples
#  Processed 1125/1435 audio samples
#  Processed 1126/1435 audio samples
#  Processed 1127/1435 audio samples
#  Processed 1128/1435 audio samples
#  Processed 1129/1435 audio samples
#  Processed 1130/1435 audio samples
#  Processed 1131/1435 audio samples
#  Processed 1132/1435 audio samples
#  Processed 1133/1435 audio samples
#  Processed 1134/1435 audio samples
#  Processed 1135/1435 audio samples
#  Processed 1136/1435 audio samples
#  Processed 1137/1435 audio samples
#  Processed 1138/1435 audio samples
#  Processed 1139/1435 audio samples
#  Processed 1140/1435 audio samples
#  Processed 1141/1435 audio samples
#  Processed 1142/1435 audio samples
#  Processed 1143/1435 audio samples
#  Processed 1144/1435 audio samples
#  Processed 1145/1435 audio samples
#  Processed 1146/1435 audio samples
#  Processed 1147/1435 audio samples
#  Processed 1148/1435 audio samples
#  Processed 1149/1435 audio samples
#  Processed 1150/1435 audio samples
#  Processed 1151/1435 audio samples
#  Processed 1152/1435 audio samples
#  Processed 1153/1435 audio samples
#  Processed 1154/1435 audio samples
#  Processed 1155/1435 audio samples
#  Processed 1156/1435 audio samples
#  Processed 1157/1435 audio samples
#  Processed 1158/1435 audio samples
#  Processed 1159/1435 audio samples
#  Processed 1160/1435 audio samples
#  Processed 1161/1435 audio samples
#  Processed 1162/1435 audio samples
#  Processed 1163/1435 audio samples
#  Processed 1164/1435 audio samples
#  Processed 1165/1435 audio samples
#  Processed 1166/1435 audio samples
#  Processed 1167/1435 audio samples
#  Processed 1168/1435 audio samples
#  Processed 1169/1435 audio samples
#  Processed 1170/1435 audio samples
#  Processed 1171/1435 audio samples
#  Processed 1172/1435 audio samples
#  Processed 1173/1435 audio samples
#  Processed 1174/1435 audio samples
#  Processed 1175/1435 audio samples
#  Processed 1176/1435 audio samples
#  Processed 1177/1435 audio samples
#  Processed 1178/1435 audio samples
#  Processed 1179/1435 audio samples
#  Processed 1180/1435 audio samples
#  Processed 1181/1435 audio samples
#  Processed 1182/1435 audio samples
#  Processed 1183/1435 audio samples
#  Processed 1184/1435 audio samples
#  Processed 1185/1435 audio samples
#  Processed 1186/1435 audio samples
#  Processed 1187/1435 audio samples
#  Processed 1188/1435 audio samples
#  Processed 1189/1435 audio samples
#  Processed 1190/1435 audio samples
#  Processed 1191/1435 audio samples
#  Processed 1192/1435 audio samples
#  Processed 1193/1435 audio samples
#  Processed 1194/1435 audio samples
#  Processed 1195/1435 audio samples
#  Processed 1196/1435 audio samples
#  Processed 1197/1435 audio samples
#  Processed 1198/1435 audio samples
#  Processed 1199/1435 audio samples
#  Processed 1200/1435 audio samples
#  Processed 1201/1435 audio samples
#  Processed 1202/1435 audio samples
#  Processed 1203/1435 audio samples
#  Processed 1204/1435 audio samples
#  Processed 1205/1435 audio samples
#  Processed 1206/1435 audio samples
#  Processed 1207/1435 audio samples
#  Processed 1208/1435 audio samples
#  Processed 1209/1435 audio samples
#  Processed 1210/1435 audio samples
#  Processed 1211/1435 audio samples
#  Processed 1212/1435 audio samples
#  Processed 1213/1435 audio samples
#  Processed 1214/1435 audio samples
#  Processed 1215/1435 audio samples
#  Processed 1216/1435 audio samples
#  Processed 1217/1435 audio samples
#  Processed 1218/1435 audio samples
#  Processed 1219/1435 audio samples
#  Processed 1220/1435 audio samples
#  Processed 1221/1435 audio samples
#  Processed 1222/1435 audio samples
#  Processed 1223/1435 audio samples
#  Processed 1224/1435 audio samples
#  Processed 1225/1435 audio samples
#  Processed 1226/1435 audio samples
#  Processed 1227/1435 audio samples
#  Processed 1228/1435 audio samples
#  Processed 1229/1435 audio samples
#  Processed 1230/1435 audio samples
#  Processed 1231/1435 audio samples
#  Processed 1232/1435 audio samples
#  Processed 1233/1435 audio samples
#  Processed 1234/1435 audio samples
#  Processed 1235/1435 audio samples
#  Processed 1236/1435 audio samples
#  Processed 1237/1435 audio samples
#  Processed 1238/1435 audio samples
#  Processed 1239/1435 audio samples
#  Processed 1240/1435 audio samples
#  Processed 1241/1435 audio samples
#  Processed 1242/1435 audio samples
#  Processed 1243/1435 audio samples
#  Processed 1244/1435 audio samples
#  Processed 1245/1435 audio samples
#  Processed 1246/1435 audio samples
#  Processed 1247/1435 audio samples
#  Processed 1248/1435 audio samples
#  Processed 1249/1435 audio samples
#  Processed 1250/1435 audio samples
#  Processed 1251/1435 audio samples
#  Processed 1252/1435 audio samples
#  Processed 1253/1435 audio samples
#  Processed 1254/1435 audio samples
#  Processed 1255/1435 audio samples
#  Processed 1256/1435 audio samples
#  Processed 1257/1435 audio samples
#  Processed 1258/1435 audio samples
#  Processed 1259/1435 audio samples
#  Processed 1260/1435 audio samples
#  Processed 1261/1435 audio samples
#  Processed 1262/1435 audio samples
#  Processed 1263/1435 audio samples
#  Processed 1264/1435 audio samples
#  Processed 1265/1435 audio samples
#  Processed 1266/1435 audio samples
#  Processed 1267/1435 audio samples
#  Processed 1268/1435 audio samples
#  Processed 1269/1435 audio samples
#  Processed 1270/1435 audio samples
#  Processed 1271/1435 audio samples
#  Processed 1272/1435 audio samples
#  Processed 1273/1435 audio samples
#  Processed 1274/1435 audio samples
#  Processed 1275/1435 audio samples
#  Processed 1276/1435 audio samples
#  Processed 1277/1435 audio samples
#  Processed 1278/1435 audio samples
#  Processed 1279/1435 audio samples
#  Processed 1280/1435 audio samples
#  Processed 1281/1435 audio samples
#  Processed 1282/1435 audio samples
#  Processed 1283/1435 audio samples
#  Processed 1284/1435 audio samples
#  Processed 1285/1435 audio samples
#  Processed 1286/1435 audio samples
#  Processed 1287/1435 audio samples
#  Processed 1288/1435 audio samples
#  Processed 1289/1435 audio samples
#  Processed 1290/1435 audio samples
#  Processed 1291/1435 audio samples
#  Processed 1292/1435 audio samples
#  Processed 1293/1435 audio samples
#  Processed 1294/1435 audio samples
#  Processed 1295/1435 audio samples
#  Processed 1296/1435 audio samples
#  Processed 1297/1435 audio samples
#  Processed 1298/1435 audio samples
#  Processed 1299/1435 audio samples
#  Processed 1300/1435 audio samples
#  Processed 1301/1435 audio samples
#  Processed 1302/1435 audio samples
#  Processed 1303/1435 audio samples
#  Processed 1304/1435 audio samples
#  Processed 1305/1435 audio samples
#  Processed 1306/1435 audio samples
#  Processed 1307/1435 audio samples
#  Processed 1308/1435 audio samples
#  Processed 1309/1435 audio samples
#  Processed 1310/1435 audio samples
#  Processed 1311/1435 audio samples
#  Processed 1312/1435 audio samples
#  Processed 1313/1435 audio samples
#  Processed 1314/1435 audio samples
#  Processed 1315/1435 audio samples
#  Processed 1316/1435 audio samples
#  Processed 1317/1435 audio samples
#  Processed 1318/1435 audio samples
#  Processed 1319/1435 audio samples
#  Processed 1320/1435 audio samples
#  Processed 1321/1435 audio samples
#  Processed 1322/1435 audio samples
#  Processed 1323/1435 audio samples
#  Processed 1324/1435 audio samples
#  Processed 1325/1435 audio samples
#  Processed 1326/1435 audio samples
#  Processed 1327/1435 audio samples
#  Processed 1328/1435 audio samples
#  Processed 1329/1435 audio samples
#  Processed 1330/1435 audio samples
#  Processed 1331/1435 audio samples
#  Processed 1332/1435 audio samples
#  Processed 1333/1435 audio samples
#  Processed 1334/1435 audio samples
#  Processed 1335/1435 audio samples
#  Processed 1336/1435 audio samples
#  Processed 1337/1435 audio samples
#  Processed 1338/1435 audio samples
#  Processed 1339/1435 audio samples
#  Processed 1340/1435 audio samples
#  Processed 1341/1435 audio samples
#  Processed 1342/1435 audio samples
#  Processed 1343/1435 audio samples
#  Processed 1344/1435 audio samples
#  Processed 1345/1435 audio samples
#  Processed 1346/1435 audio samples
#  Processed 1347/1435 audio samples
#  Processed 1348/1435 audio samples
#  Processed 1349/1435 audio samples
#  Processed 1350/1435 audio samples
#  Processed 1351/1435 audio samples
#  Processed 1352/1435 audio samples
#  Processed 1353/1435 audio samples
#  Processed 1354/1435 audio samples
#  Processed 1355/1435 audio samples
#  Processed 1356/1435 audio samples
#  Processed 1357/1435 audio samples
#  Processed 1358/1435 audio samples
#  Processed 1359/1435 audio samples
#  Processed 1360/1435 audio samples
#  Processed 1361/1435 audio samples
#  Processed 1362/1435 audio samples
#  Processed 1363/1435 audio samples
#  Processed 1364/1435 audio samples
#  Processed 1365/1435 audio samples
#  Processed 1366/1435 audio samples
#  Processed 1367/1435 audio samples
#  Processed 1368/1435 audio samples
#  Processed 1369/1435 audio samples
#  Processed 1370/1435 audio samples
#  Processed 1371/1435 audio samples
#  Processed 1372/1435 audio samples
#  Processed 1373/1435 audio samples
#  Processed 1374/1435 audio samples
#  Processed 1375/1435 audio samples
#  Processed 1376/1435 audio samples
#  Processed 1377/1435 audio samples
#  Processed 1378/1435 audio samples
#  Processed 1379/1435 audio samples
#  Processed 1380/1435 audio samples
#  Processed 1381/1435 audio samples
#  Processed 1382/1435 audio samples
#  Processed 1383/1435 audio samples
#  Processed 1384/1435 audio samples
#  Processed 1385/1435 audio samples
#  Processed 1386/1435 audio samples
#  Processed 1387/1435 audio samples
#  Processed 1388/1435 audio samples
#  Processed 1389/1435 audio samples
#  Processed 1390/1435 audio samples
#  Processed 1391/1435 audio samples
#  Processed 1392/1435 audio samples
#  Processed 1393/1435 audio samples
#  Processed 1394/1435 audio samples
#  Processed 1395/1435 audio samples
#  Processed 1396/1435 audio samples
#  Processed 1397/1435 audio samples
#  Processed 1398/1435 audio samples
#  Processed 1399/1435 audio samples
#  Processed 1400/1435 audio samples
#  Processed 1401/1435 audio samples
#  Processed 1402/1435 audio samples
#  Processed 1403/1435 audio samples
#  Processed 1404/1435 audio samples
#  Processed 1405/1435 audio samples
#  Processed 1406/1435 audio samples
#  Processed 1407/1435 audio samples
#  Processed 1408/1435 audio samples
#  Processed 1409/1435 audio samples
#  Processed 1410/1435 audio samples
#  Processed 1411/1435 audio samples
#  Processed 1412/1435 audio samples
#  Processed 1413/1435 audio samples
#  Processed 1414/1435 audio samples
#  Processed 1415/1435 audio samples
#  Processed 1416/1435 audio samples
#  Processed 1417/1435 audio samples
#  Processed 1418/1435 audio samples
#  Processed 1419/1435 audio samples
#  Processed 1420/1435 audio samples
#  Processed 1421/1435 audio samples
#  Processed 1422/1435 audio samples
#  Processed 1423/1435 audio samples
#  Processed 1424/1435 audio samples
#  Processed 1425/1435 audio samples
#  Processed 1426/1435 audio samples
#  Processed 1427/1435 audio samples
#  Processed 1428/1435 audio samples
#  Processed 1429/1435 audio samples
#  Processed 1430/1435 audio samples
#  Processed 1431/1435 audio samples
#  Processed 1432/1435 audio samples
#  Processed 1433/1435 audio samples
#  Processed 1434/1435 audio samples
#  Processed 1435/1435 audio samples

# %% [markdown]
# Let's see what the features we extracted look like, **also for saving both the features matrix as well as emotions array, we need to convert them to pandas dataframe.**

# %%
print(f'\nAudio samples represented: {features.shape[0]}')
print(f'Numerical features extracted per sample: {features.shape[1]}')
features_df = pd.DataFrame(features) # make it pretty for display


#making dataframe for emotions as well
emotions_df = pd.DataFrame(emotions) # make it pretty for display

features_df
# Out:
# Audio samples represented: 1435
# Numerical features extracted per sample: 180
#            0         1         2         3         4         5         6    \
# 0     0.631892  0.630022  0.627687  0.616110  0.600657  0.597530  0.618320
# 1     0.513956  0.485253  0.450026  0.446813  0.454777  0.430608  0.462393
# 2     0.555037  0.531048  0.513510  0.510403  0.540032  0.569965  0.590901
# 3     0.657369  0.627190  0.565196  0.516516  0.496828  0.512128  0.581021
# 4     0.465189  0.462528  0.449644  0.460654  0.476605  0.492283  0.516932
# ...        ...       ...       ...       ...       ...       ...       ...
# 1430  0.512831  0.459670  0.457748  0.481753  0.504849  0.531603  0.565015
# 1431  0.530808  0.473593  0.469681  0.502935  0.530213  0.572539  0.616313
# 1432  0.658923  0.583768  0.554111  0.550254  0.595422  0.627516  0.613072
# 1433  0.671404  0.612528  0.576918  0.610196  0.628637  0.636579  0.646750
# 1434  0.552523  0.506846  0.484210  0.513962  0.522900  0.581985  0.627232
#
#            7         8         9    ...       170       171       172  \
# 0     0.623001  0.654439  0.622531  ...  0.500898  1.291016 -0.041403
# 1     0.471200  0.547599  0.570421  ...  1.407687  2.243373  3.296909
# 2     0.624320  0.610652  0.553379  ...  2.155205  1.332956  0.793206
# 3     0.640896  0.669427  0.657833  ...  4.048691  4.406282  3.696834
# 4     0.541659  0.566635  0.542519  ... -1.553281 -3.932139 -1.924470
# ...        ...       ...       ...  ...       ...       ...       ...
# 1430  0.548620  0.562034  0.518914  ... -2.685926 -0.273525 -0.334638
# 1431  0.606503  0.600060  0.566500  ... -3.408013 -2.080451 -1.396417
# 1432  0.601895  0.598662  0.588482  ... -1.213999  0.523614  2.151223
# 1433  0.661407  0.708094  0.721780  ... -2.712269 -0.374594  1.243293
# 1434  0.596429  0.608828  0.611255  ... -4.336431 -2.729545 -2.345471
#
#            173       174       175       176       177       178       179
# 0     0.612038  1.309492  0.024909 -0.319914  1.399153 -0.071440  2.555313
# 1     2.019585  1.884217  1.912023  2.614335  4.236218  4.390153  7.899289
# 2     1.455154  3.509222  1.141562  0.403321  0.952418 -0.035216  0.434507
# 3     2.892697  3.987929  2.539243  2.454156  2.174061  2.512988  6.401701
# 4    -2.874562 -2.029576  0.234563  1.221652  1.779323  2.259865  3.431705
# ...        ...       ...       ...       ...       ...       ...       ...
# 1430 -1.417649  0.027186 -0.992872  0.093618  0.838772  1.796148  2.140811
# 1431 -1.721295  0.210375  1.284015 -0.077923 -0.538108  1.526047  0.089963
# 1432  1.493259  1.924983  1.768824  0.536857  1.229263  1.358520  1.091180
# 1433  2.059977  1.867802  3.814509  3.389066  4.373001  5.710487  3.882066
# 1434 -1.595785  0.104440  1.286885  1.332131  1.599231  2.778275  2.262775
#
# [1435 rows x 180 columns]

# %% [markdown]
# We have a matrix of dim 1435 x 180. Looks good - 1435 audio samples, one per row, with a series of
# 180 numerical features for each sample.
#
# **Each of the 1435 feature arrays has 180 features composed of 12 chromagram pitch classes + 128 mel spectrogram bands + 40 MFC coefficients.**

# %% [markdown]
# Now we will save our features matrix and emotions array in excel file we dont have to compute them everytime we run the notebook, we can just load them from the excel file whenever required. Make sure to change the path to according to your drive.

# %%
features_df.to_excel('/content/drive/MyDrive/features_Ravdess_only.xlsx')
emotions_df.to_excel('/content/drive/MyDrive/emotions_Ravdess_only.xlsx')

# %% [markdown]
# ## Load pre-saved Dataset

# %% [markdown]
# Once saved you only need to load them later by running the cell below, and **skip every cell above** except for the one in which we import libraries.

# %%
features=pd.read_excel('/content/drive/MyDrive/features_Ravdess_only.xlsx',index_col=0)
emotions=pd.read_excel('/content/drive/MyDrive/emotions_Ravdess_only.xlsx',index_col=0)

# %% [markdown]
# let's see if they have been loaded correctly!

# %%
features.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.631892  0.630022  0.627687  0.616110  0.600657  0.597530  0.618320
# 1  0.513956  0.485253  0.450026  0.446813  0.454777  0.430608  0.462393
# 2  0.555037  0.531048  0.513510  0.510403  0.540032  0.569965  0.590901
# 3  0.657369  0.627190  0.565196  0.516516  0.496828  0.512128  0.581021
# 4  0.465189  0.462528  0.449644  0.460654  0.476605  0.492283  0.516932
#
#         7         8         9    ...       170       171       172       173  \
# 0  0.623001  0.654439  0.622531  ...  0.500898  1.291016 -0.041403  0.612038
# 1  0.471200  0.547599  0.570421  ...  1.407687  2.243373  3.296909  2.019585
# 2  0.624320  0.610652  0.553379  ...  2.155205  1.332956  0.793206  1.455154
# 3  0.640896  0.669427  0.657833  ...  4.048691  4.406282  3.696834  2.892697
# 4  0.541659  0.566635  0.542519  ... -1.553281 -3.932139 -1.924470 -2.874562
#
#         174       175       176       177       178       179
# 0  1.309492  0.024909 -0.319914  1.399153 -0.071440  2.555313
# 1  1.884217  1.912023  2.614335  4.236218  4.390153  7.899289
# 2  3.509222  1.141562  0.403321  0.952418 -0.035216  0.434507
# 3  3.987929  2.539243  2.454156  2.174061  2.512988  6.401701
# 4 -2.029576  0.234563  1.221652  1.779323  2.259865  3.431705
#
# [5 rows x 180 columns]

# %% [markdown]
# Let's see what the features we extracted look like:

# %%
print(f'\nAudio samples represented: {features.shape[0]}')
print(f'Numerical features extracted per sample: {features.shape[1]}')
features_df = pd.DataFrame(features) # make it pretty for display
labels_df=pd.DataFrame(emotions)
# Out:
# Audio samples represented: 1435
# Numerical features extracted per sample: 180

# %% [markdown]
# We have a matrix of dim 1435 x 180. Looks good - 1435 audio samples, one per row, with a series of
# 180 numerical features for each sample.
#
# **Each of the 1435 feature arrays has 180 features composed of 12 chromagram pitch classes + 128 mel spectrogram bands + 40 MFC coefficients.**

# %% [markdown]
# Let's see the class balance of our dataset:

# %%
# plot emotions
plt.figure(figsize=(35,4))
plt.subplot(1,3,1)
#np.unique returns ordered list of unique elements and count of each element
emotion_list, count = np.unique(emotions, return_counts=True)
print(emotion_list,count)
plt.bar(x=range(8), height=count)
plt.xticks(ticks=range(8), labels = [emotion for emotion in emotion_list],fontsize=10)
plt.xlabel('Emotion')
plt.tick_params(labelsize=16)
plt.ylabel('Number of Samples')
plt.show()
# Out:
# ['angry' 'calm' 'disgust' 'fearful' 'happy' 'neutral' 'sad' 'surprised'] [192 190 192 191 191  96 192 191]

# %% [markdown]
# **Great, the classes appear to be balanced. That makes the task easier.** All emotions _except_ the neutral class have a "strong" intensity so there are half as many neutral samples. That might have an impact.

# %% [markdown]
# ### Feature Scaling
# To properly train most machine learning models on _most_ datasets, we first need to scale our features. **This is crucial for models which compute distances between data, and especially critical for DNNs**: If there is a difference in the variance of features simply because of their possible range of values, then a model will learn that the features with the greatest variance are the most important. However, **differences in the variance of unscaled features belonging to different and unknown distributions is an inappropriate measure of importance.** Let's check our features' properties:

# %%
# We would usually use df.describe(), but it provides a bit of a mess of information we don't need at the moment.
def print_features(df):
    # Check chromagram feature values
    features_df_chromagram = df.loc[:,:11]
    chroma_min = features_df_chromagram.min().min()
    chroma_max = features_df_chromagram.max().max()
    # stack all features into a single series so we don't get a mean of means or stdev of stdevs
    chroma_mean = features_df_chromagram.stack().mean()
    chroma_stdev = features_df_chromagram.stack().std()
    print(f'12 Chromagram features:       \
    min = {chroma_min:.3f}, \
    max = {chroma_max:.3f}, \
    mean = {chroma_mean:.3f}, \
    deviation = {chroma_stdev:.3f}')

    # Check mel spectrogram feature values
    features_df_melspectrogram = df.loc[:,12:139]
    mel_min = features_df_melspectrogram.min().min()
    mel_max = features_df_melspectrogram.max().max()
    # stack all features into a single series so we don't get a mean of means or stdev of stdevs
    mel_mean = features_df_melspectrogram.stack().mean()
    mel_stdev = features_df_melspectrogram.stack().std()
    print(f'\n128 Mel Spectrogram features: \
    min = {mel_min:.3f}, \
    max = {mel_max:.3f}, \
    mean = {mel_mean:.3f}, \
    deviation = {mel_stdev:.3f}')

    # Check MFCC feature values
    features_df_mfcc = df.loc[:,140:179]
    mfcc_min = features_df_mfcc.min().min()
    mfcc_max = features_df_mfcc.max().max()
    # stack all features into a single series so we don't get a mean of means or stdev of stdevs
    mfcc_mean = features_df_mfcc.stack().mean()
    mfcc_stdev = features_df_mfcc.stack().std()
    print(f'\n40 MFCC features:             \
    min = {mfcc_min:.3f},\
    max = {mfcc_max:.3f},\
    mean = {mfcc_mean:.3f},\
    deviation = {mfcc_stdev:.3f}')

print_features(features_df)
# Out:
# 12 Chromagram features:           min = 0.310,     max = 0.874,     mean = 0.666,     deviation = 0.085
#
# 128 Mel Spectrogram features:     min = 0.000,     max = 149.208,     mean = 0.188,     deviation = 1.600
#
# 40 MFCC features:                 min = -873.242,    max = 115.126,    mean = -14.626,    deviation = 98.494

# %% [markdown]
# **There's an obvious imbalance in the variance our features; Our features indeed belong to very different distributions:** our MFC coefficients' deviation is greater than the other features by orders of magnitude. That does not mean MFC coefficients are the most important feature, but rather it is a property of the way they are computed.  We will certainly need to scale this feature set.
#
# We have the choice of sklearn's StandardScaler and MinMaxScaler. Standard scaling subtracts the mean of each feature and divides it by the standard deviation of that feature, producing features with mean at zero and unit variance - that is, a variance and standard deviation of 1. Min-Max scaling transforms each feature to be within a bounded interval that we specify.
#
# In practice, **MinMax scaling is especially useful when we know our features should be in a bounded interval**, such as pixel values in [0,255], while **standard scaling is perhaps more practical for features with unknown distributions** because centering the features at zero-mean with a standard deviation of 1 means extreme values will have less of an impact on the model's learned weights, i.e. the model is less sensitive to outliers.
#
# We'll create MinMax scaled features as well so we can give them a try later on to confirm that standard scaling is better in the absence of knowledge on the appropriate distribution for a dataset's features.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

scaler = StandardScaler()
# keep our unscaled features just in case we need to process them alternatively
features_scaled = features
features_scaled = scaler.fit_transform(features_scaled)

scaler = MinMaxScaler()
# keep our unscaled features just in case we need to process them alternatively
features_minmax = features
features_minmax = scaler.fit_transform(features_minmax)

# %% [markdown]
# Make sure our features are properly scaled:

# %%
print('\033[1m'+'Standard Scaling:\n'+'\033[0m')
features_scaled_df = pd.DataFrame(features_scaled)
print_features(features_scaled_df)

print('\n\n\033[1m'+'MinMax Scaling:\n'+'\033[0m')
features_minmax_df = pd.DataFrame(features_minmax)
print_features(features_minmax_df)
# Out:
# Standard Scaling:
#
# 12 Chromagram features:           min = -3.958,     max = 2.644,     mean = -0.000,     deviation = 1.000
#
# 128 Mel Spectrogram features:     min = -0.475,     max = 36.480,     mean = -0.000,     deviation = 1.000
#
# 40 MFCC features:                 min = -4.209,    max = 6.240,    mean = 0.000,    deviation = 1.000
#
#
# MinMax Scaling:
#
# 12 Chromagram features:           min = 0.000,     max = 1.000,     mean = 0.611,     deviation = 0.181
#
# 128 Mel Spectrogram features:     min = 0.000,     max = 1.000,     mean = 0.015,     deviation = 0.061
#
# 40 MFCC features:                 min = 0.000,    max = 1.000,    mean = 0.406,    deviation = 0.166

# %% [markdown]
# Perfect. Zero mean and unit variance for standard scaling and in the range [0,1] for MinMax scaling - a default when we don't specify values. We can now move on to building predictive models for these features.

# %% [markdown]
# ## The MLP Model for Classification
# We're going to first try a Multilayer Perceptron (MLP) Classifier, a simple artificial neural network (ANN) model well-suited for predictions trained on labelled inputs. Note that an MLP model can be trained for regression just as well. An MLP network consists of an input layer, _n_ hidden layers, and an output layer. The logic of the network depends on its weights: An array [w<sub>0</sub>-w<sub>i</sub>] for _each node_ in all layers, one weight value for each node-node connection (edge) in the graph representation (a matrix _W_ for the network). We also have biases, an array [b<sub>0</sub>-b<sub>j</sub>] for _each layer_, one value for each node (a matrix _B_ for the network). I'll speak more to its architechture below.

# %% [markdown]
# <img src="https://github.com/IAT-ExploringAI-2024/Week4-Neural_Network/blob/main/mlp.png?raw=true" width=500 height=500 />

# %% [markdown]
# ###Training: The 80/20 Split and Validation
# In order to compare models, we'll have to evaluate their performance. The simplest method to do so is to train a model on a portion of our dataset and test it on the remainder. We'll use sklearn's train_test_split to create a standard 80/20 train/test split. The model is fit on 80% of
# the data and tested for performance against 20% of the data, which it has never seen in training - also called the hold-out set.
#
# More accurately, the proper modality for training and scoring a model is to
# 1. Fit/train our model on a _training_ set,
# 2. Evaluate the model on a _validation_ set to tune the hyperparameters for better performance,
# 3. Finally score our model's true performance - its **generalizability** - against a _test_ set, aka the hold-out set.
# 4. Repeat from 2. **Do not tune the model to score well on the test set**.
#
# Different set ratios are used in this approach - a usual example is 60/20/20 train/validation/test.
#
# For simplicity, we're going to start with an 80/20 train/test split. The model will be trained on all the training data, and we will check its performance on the test data. Define unscaled and scaled training and test sets:

# %%
from sklearn.model_selection import train_test_split
############# Unscaled test/train set #############
X_train, X_test, y_train, y_test = train_test_split(
    features,
    emotions,
    test_size=0.2,
    random_state=69
)

############ Standard Scaled test/train set ###########
# The labels/classes (y_train, y_test) never change, keep old values
X_train_scaled, X_test_scaled, _, _ = train_test_split(
    features_scaled,
    emotions,
    test_size=0.2,
    random_state=69
)

############# MinMax Scaled test/train set ###############
# The labels/classes (y_train, y_test) never change, keep old values
X_train_minmax, X_test_minmax, _, _ = train_test_split(
    features_scaled,
    emotions,
    test_size=0.2,
    random_state=69
)

# %% [markdown]
# ### MLP Initialization

# %% [markdown]
# We initialize an MLP classification model with random weights and biases at zero, the standard modality. There are techniques for determining optimal weight initialization; the initial distribution of weights is incrediby important because they impact the direction of the gradient and will determine how fast and whether at all a model's loss function will converge.
#
# We'll try the off-the-shelf MLP model that comes with sklearn. Using default settings for neural networks is not a good idea in general - and **checking a model's performance on test data before tuning the model on a validation set is incorrect methodology**... but for demonstrative purposes:

# %%
from sklearn.neural_network import MLPClassifier

# Default 'off-the-shelf' MLP from sklearn
model = MLPClassifier(
    random_state = 69
)

#################### unscaled features #####################
X_train, X_test, y_train, y_test = train_test_split(
    features,
    emotions,
    test_size=0.2,
    random_state=69
)

model.fit(X_train, y_train)

print(f'Possible emotions predicted by model:{model.classes_}')
print(f'Unscaled MLP Model\'s accuracy on training set is {100*model.score(X_train, y_train):.2f}%')
print(f'Unscaled MLP Model\'s accuracy on test set is {100*model.score(X_test, y_test):.2f}%')
# Out:
# Possible emotions predicted by model:['angry' 'calm' 'disgust' 'fearful' 'happy' 'neutral' 'sad' 'surprised']
# Unscaled MLP Model's accuracy on training set is 67.42%
# Unscaled MLP Model's accuracy on test set is 53.31%

# %% [markdown]
# Great - we expected terrible performance with no thought given to the model or feature scale. Otherwise, what would a machine learning engineer do? At any rate, we at least know that our model's possible predictions - classes - are correct, and it's even doing a little better than guessing with a 1/8 (12.5%) chance. More than we can ask for with this approach.
#
# Let's see how feature scaling impacts the performance of the MLP:

# %%
#################### minmax scaled #######################
# Rebuild the training set from the minmax scaled features
# The labels/classes (y_train, y_test) never change, keep old values
X_train_minmax, X_test_minmax, _, _ = train_test_split(
    features_minmax,
    emotions,
    test_size=0.2,
    random_state=69
)

# Fit the model again on the minmax scaled features
model.fit(X_train_minmax, y_train)

print(f'MinMax scaled MLP Model\'s accuracy on training set is {100*model.score(X_train_minmax, y_train):.2f}%')
print(f'MinMax sacled MLP Model\'s accuracy on test set is {100*model.score(X_test_minmax, y_test):.2f}%\n')

#################### standard scaled #######################
# Rebuild the training set from the standard scaled features
# The labels/classes (y_train, y_test) never change, keep old values
X_train_scaled, X_test_scaled, _, _ = train_test_split(
    features_scaled,
    emotions,
    test_size=0.2,
    random_state=69
)
# Fit the model again on the scaled features
model.fit(X_train_scaled, y_train)

print(f'Standard scaled MLP Model\'s accuracy on training set is {100*model.score(X_train_scaled, y_train):.2f}%')
print(f'Standard scaled MLP Model\'s accuracy on test set is {100*model.score(X_test_scaled, y_test):.2f}%')
# Out:
# MinMax scaled MLP Model's accuracy on training set is 63.76%
# MinMax sacled MLP Model's accuracy on test set is 51.92%
#
# Standard scaled MLP Model's accuracy on training set is 99.65%
# Standard scaled MLP Model's accuracy on test set is 68.64%

# %% [markdown]
# That's more like it. Standard scaling is indeed the way to go here. **It is important to consider choice of scaling method, if necessary, as a crucial hyperparameter of a model.** Skipping this step or choosing the wrong scaling method can render even the most appropriate features, worthless.
#
# Perhaps with some effort we can make the MLP model work for us. We'll try to give it a fighting chance by actually paying attention to what it's doing:

# %% [markdown]
# ### Choice of Hyperparameters
# Before training a network we must select hyperparameters, which determine the network's learning behaviour - hyperparameters determine how the network learns its weights and biases, while the network parameters determine what those weights and biases are. Each type of model (SVC, MLP, Random Forests, etc...) come with their own set of hyperparameters, and each type of optimization algorithm does as well. We may use the same optimization algorithm for two different models, but memorizing the best hyperparameters for one model won't help us with any other model and likely, not any other task even with the same model.
#
# The MLP model has a number of hyperparameters significant to its learning behaviour:
# - **Alpha**: Constrains the model's weights to be within a certain bound to address overfitting; in range [0,1], parameterizes l2 penalty which defines how steeply the cost function modifies weights in proportion to their magnitude, i.e. **regularizes** the cost function and so is also called the regularization term. In practice, **higher alpha more steeply penalizes large weights.**
# - **Activation function:** Determines the output of a neuron by the transformation applied to the set of inputs to that neuron
# - **Solver:** Algorithm(s) used for optimization of our weights (with backpropogation **gradient descent** in the case of the MLP classifier)
# - **Learning rate:** How large of a change the optimization algorithm makes to the model's weights at each training iteration, in
# - **Epsilon:** Unique to the 'adam' solver, numerical stability - to avoid divison by zero.
#
# ### Network Architecture
# The input layer of our MLP neural network is the size of our feature space - that is, one neuron per feature. In our case, 180 input neurons constitute the input layer. Since we are performing multiclass classification, our MLP network has one neuron in its output layer for each class label. In our case 8 output neurons, one per emotion.
#
# The size of our hidden layer is of interest and a more dubious task than choosing other hyperparameters, because the behaviour of different numbers and sizes of hidden layers is much less transparent. There are many opinions on the matter, but there is relative consensus in that **many tasks rarely benefit from more than one hidden layer**, i.e. one hidden layer is sufficient in most cases. The number of neurons in that hidden layer is a less obvious choice, but it seems from literature that a number between the input layer and output layer size is a good starting point. At any rate, the time complexity of training our model scales exponentially with the number of hidden layers, so let's keep that number at the minimum, and likely optimum of 1.
#
# ### Hyperparameter Optimization and Grid Search
# We're going to take advantage of the grid search cross-validation algorithm to find the best hyperparameters for us.
#
# Grid search is relatively simple to understand - we specify a set of candidate values for each hyperparameter, and grid search tries all combinations of those hyperparameter values to build and score potential models against our training and validation data. Grid search scores sets of hyperparameters by building a validation set from the training set we give it.
#
# We initialize the MLP classifier with the hyperparameters we will keep constant, those less likely to have a significant impact on the model's performance. We shouldn't use grid search to look for hyperparameters we can easily tune later, such as the number of training iterations (# of forward+backward passes through the network for each _batch_ of training samples); if we do so, we significantly inflate the computational cost with little return. For these hyperparameters we should choose values which are usually reasonable from a literature search (...from stackexchange).
#
# In case grid search is too expensive for the hyperparameter grid we specify, **Randomized Grid Search** can be used to sample a fixed number of hyperparameter combinations from the distribution of settings we define.
#
# We define a random state so that we can accurately compare any improvements we make to the model.
#
# We also define a **batch size**: the number of training samples included in one forward (input) and backward (error) pass of the model, which is one **iteration**. A batch size in range [1, #samples] is common - in our case, [1,1440\*0.8]. [**Mini-batches**](https://machinelearningmastery.com/gentle-introduction-mini-batch-gradient-descent-configure-batch-size/) in the set [32, 64, 128, 256] are usually encouraged, especially on smaller datasets. **Smaller batches** cause more frequent weight updates and faster convergence - faster learning - though each update is less accurate compared to a larger batch. **Larger batches** train on a larger set of inputs simultaneously, and so may optimize loss better at each iteration due to a more accurate gradient computation - however, large batches may encourage overfitting and worsen generalization error.

# %%
from sklearn.model_selection import GridSearchCV
from joblib import parallel_backend


# Now that we know standard scaling is best for our features, we'll use those for our training and test sets
X_train, X_test, y_train, y_test = train_test_split(
    features_scaled,
    emotions,
    test_size=0.2,
    random_state=69
)

# Initialize the MLP Classifier and choose parameters we want to keep constant
model = MLPClassifier(
    # tune batch size later
    batch_size=256,
    # keep random state constant to accurately compare subsequent models
    random_state=69
)

# Choose the grid of hyperparameters we want to use for Grid Search to build our candidate models
parameter_space = {
    # A single hidden layer of size between 8 (output classes) and 180 (input features) neurons is most probable
    # It's a bad idea at guessing the number of hidden layers to have
    # ...but we'll give 2 and 3 hidden layers a shot to reaffirm our suspicions that 1 is best
    'hidden_layer_sizes': [(180,), (300,),(100,50,)],
    'activation': ['relu', 'logistic'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.001, 0.01],
    #'epsilon': [1e-08, 0.1],
    'learning_rate': ['adaptive', 'constant']
}

# Create a grid search object which will store the scores and hyperparameters of all candidate models
grid = GridSearchCV(
    model,
    parameter_space,
    cv=10,
    n_jobs=-1,
    verbose=10)
# Fit the models specified by the parameter grid
with parallel_backend('multiprocessing'):
    grid.fit(X_train, y_train)


# get the best hyperparameters from grid search object with its best_params_ attribute
print('Best parameters found:\n', grid.best_params_)
# Out:
# [CV 2/10; 1/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd[CV 1/10; 1/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd
#
# Fitting 10 folds for each of 48 candidates, totalling 480 fits
# [CV 1/10; 1/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd;, score=0.496 total time=   6.5s
# [CV 3/10; 1/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd
# [CV 2/10; 1/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd;, score=0.461 total time=   6.6s
# [CV 4/10; 1/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd
# [CV 3/10; 1/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd;, score=0.478 total time=   8.3s
# [CV 5/10; 1/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd
# [CV 4/10; 1/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd;, score=0.426 total time=   9.0s
# [CV 6/10; 1/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd
# [CV 5/10; 1/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd;, score=0.400 total time=   7.0s
# [CV 7/10; 1/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd
# [CV 6/10; 1/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd;, score=0.496 total time=   6.5s
# [CV 8/10; 1/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd
# [CV 7/10; 1/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd;, score=0.557 total time=   5.7s
# [CV 9/10; 1/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd
# [CV 8/10; 1/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd;, score=0.557 total time=   6.3s
# [CV 10/10; 1/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd
# [CV 9/10; 1/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd;, score=0.491 total time=   7.3s
# [CV 1/10; 2/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam
# [CV 10/10; 1/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd;, score=0.553 total time=   6.5s
# [CV 2/10; 2/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam
# [CV 2/10; 2/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam;, score=0.583 total time=   5.6s[CV 1/10; 2/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam;, score=0.661 total time=   5.8s
#
# [CV 3/10; 2/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam[CV 4/10; 2/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam
#
# [CV 3/10; 2/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam;, score=0.626 total time=   7.9s
# [CV 5/10; 2/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam
# [CV 4/10; 2/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam;, score=0.557 total time=   8.3s
# [CV 6/10; 2/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam
# [CV 5/10; 2/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam;, score=0.522 total time=   6.1s
# [CV 7/10; 2/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam
# [CV 6/10; 2/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam;, score=0.626 total time=   5.9s
# [CV 8/10; 2/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam
# [CV 7/10; 2/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam;, score=0.713 total time=   7.9s
# [CV 9/10; 2/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam
# [CV 8/10; 2/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam;, score=0.652 total time=   8.0s
# [CV 10/10; 2/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam
# [CV 9/10; 2/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam;, score=0.632 total time=   6.9s
# [CV 1/10; 3/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd
# [CV 10/10; 2/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam;, score=0.632 total time=   7.4s
# [CV 2/10; 3/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd
# [CV 1/10; 3/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd;, score=0.496 total time=   9.1s
# [CV 3/10; 3/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd
# [CV 2/10; 3/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd;, score=0.461 total time=   8.6s
# [CV 4/10; 3/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd
# [CV 3/10; 3/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd;, score=0.478 total time=   5.5s
# [CV 5/10; 3/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd
# [CV 4/10; 3/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd;, score=0.426 total time=   5.4s
# [CV 6/10; 3/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd
# [CV 5/10; 3/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd;, score=0.400 total time=   7.2s
# [CV 7/10; 3/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd
# [CV 6/10; 3/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd;, score=0.496 total time=   7.7s
# [CV 8/10; 3/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd
# [CV 7/10; 3/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd;, score=0.557 total time=   5.7s
# [CV 9/10; 3/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd
# [CV 8/10; 3/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd;, score=0.557 total time=   5.5s
# [CV 10/10; 3/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd
# [CV 9/10; 3/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd;, score=0.491 total time=   5.6s
# [CV 1/10; 4/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam
# [CV 10/10; 3/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd;, score=0.553 total time=   5.9s
# [CV 2/10; 4/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam
# [CV 1/10; 4/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam;, score=0.661 total time=   7.6s
# [CV 3/10; 4/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam
# [CV 2/10; 4/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam;, score=0.583 total time=   7.4s
# [CV 4/10; 4/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam
# [CV 3/10; 4/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam;, score=0.626 total time=   6.2s
# [CV 5/10; 4/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam
# [CV 4/10; 4/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam;, score=0.557 total time=   7.0s
# [CV 6/10; 4/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam
# [CV 5/10; 4/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam;, score=0.522 total time=   8.6s
# [CV 7/10; 4/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam
# [CV 6/10; 4/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam;, score=0.626 total time=   8.5s
# [CV 8/10; 4/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam
# [CV 7/10; 4/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam;, score=0.713 total time=   6.2s
# [CV 9/10; 4/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam
# [CV 8/10; 4/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam;, score=0.652 total time=   6.6s
# [CV 10/10; 4/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam
# [CV 9/10; 4/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam;, score=0.632 total time=   8.4s
# [CV 1/10; 5/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd
# [CV 10/10; 4/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam;, score=0.632 total time=   7.8s
# [CV 2/10; 5/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd
# [CV 1/10; 5/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd;, score=0.530 total time=   8.2s
# [CV 3/10; 5/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd
# [CV 2/10; 5/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd;, score=0.435 total time=   9.4s
# [CV 4/10; 5/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd
# [CV 3/10; 5/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd;, score=0.496 total time=   9.4s
# [CV 5/10; 5/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd
# [CV 4/10; 5/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd;, score=0.417 total time=   8.4s
# [CV 6/10; 5/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd
# [CV 5/10; 5/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd;, score=0.452 total time=   9.8s
# [CV 7/10; 5/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd
# [CV 6/10; 5/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd;, score=0.557 total time=  10.2s
# [CV 8/10; 5/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd
# [CV 7/10; 5/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd;, score=0.548 total time=   7.6s
# [CV 9/10; 5/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd
# [CV 8/10; 5/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd;, score=0.548 total time=   8.0s
# [CV 10/10; 5/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd
# [CV 9/10; 5/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd;, score=0.491 total time=   9.7s
# [CV 1/10; 6/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam
# [CV 10/10; 5/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd;, score=0.544 total time=   9.8s
# [CV 2/10; 6/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam
# [CV 1/10; 6/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam;, score=0.643 total time=  10.1s
# [CV 3/10; 6/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam
# [CV 2/10; 6/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam;, score=0.635 total time=  10.8s
# [CV 4/10; 6/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam
# [CV 3/10; 6/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam;, score=0.670 total time=   9.2s
# [CV 5/10; 6/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam
# [CV 4/10; 6/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam;, score=0.600 total time=   8.3s
# [CV 6/10; 6/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam
# [CV 5/10; 6/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam;, score=0.600 total time=  10.7s
# [CV 7/10; 6/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam
# [CV 6/10; 6/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam;, score=0.670 total time=  10.9s
# [CV 8/10; 6/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam
# [CV 7/10; 6/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam;, score=0.748 total time=  12.3s
# [CV 9/10; 6/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam
# [CV 8/10; 6/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam;, score=0.670 total time=  12.8s
# [CV 10/10; 6/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam
# [CV 9/10; 6/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam;, score=0.711 total time=   8.8s
# [CV 1/10; 7/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd
# [CV 10/10; 6/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam;, score=0.649 total time=  10.1s
# [CV 2/10; 7/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd
# [CV 1/10; 7/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd;, score=0.530 total time=  10.1s
# [CV 3/10; 7/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd
# [CV 2/10; 7/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd;, score=0.435 total time=   8.4s
# [CV 4/10; 7/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd
# [CV 3/10; 7/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd;, score=0.496 total time=   9.2s
# [CV 5/10; 7/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd
# [CV 4/10; 7/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd;, score=0.417 total time=  10.1s
# [CV 6/10; 7/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd
# [CV 5/10; 7/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd;, score=0.452 total time=   8.4s
# [CV 7/10; 7/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd
# [CV 6/10; 7/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd;, score=0.557 total time=   8.0s
# [CV 8/10; 7/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd
# [CV 7/10; 7/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd;, score=0.548 total time=   9.9s
# [CV 9/10; 7/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd
# [CV 8/10; 7/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd;, score=0.548 total time=  10.1s
# [CV 10/10; 7/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd
# [CV 9/10; 7/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd;, score=0.491 total time=   7.7s
# [CV 1/10; 8/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam
# [CV 10/10; 7/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd;, score=0.544 total time=   9.8s
# [CV 2/10; 8/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam
# [CV 1/10; 8/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam;, score=0.643 total time=  10.6s
# [CV 3/10; 8/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam
# [CV 2/10; 8/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam;, score=0.635 total time=   8.7s
# [CV 4/10; 8/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam
# [CV 3/10; 8/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam;, score=0.670 total time=  10.7s
# [CV 5/10; 8/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam
# [CV 4/10; 8/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam;, score=0.600 total time=  10.6s
# [CV 6/10; 8/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam
# [CV 5/10; 8/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam;, score=0.600 total time=   8.8s
# [CV 7/10; 8/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam
# [CV 6/10; 8/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam;, score=0.670 total time=  10.6s
# [CV 8/10; 8/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam
# [CV 7/10; 8/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam;, score=0.748 total time=  10.5s
# [CV 9/10; 8/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam
# [CV 8/10; 8/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam;, score=0.670 total time=   8.7s
# [CV 10/10; 8/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam
# [CV 9/10; 8/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam;, score=0.711 total time=  10.5s
# [CV 1/10; 9/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd
# [CV 10/10; 8/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam;, score=0.649 total time=  10.7s
# [CV 2/10; 9/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd
# [CV 1/10; 9/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd;, score=0.496 total time=   5.1s
# [CV 3/10; 9/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd
# [CV 2/10; 9/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd;, score=0.383 total time=   5.7s
# [CV 4/10; 9/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd
# [CV 3/10; 9/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd;, score=0.470 total time=   6.6s
# [CV 5/10; 9/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd
# [CV 4/10; 9/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd;, score=0.348 total time=   6.9s
# [CV 6/10; 9/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd
# [CV 5/10; 9/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd;, score=0.409 total time=   5.5s
# [CV 7/10; 9/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd
# [CV 6/10; 9/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd;, score=0.487 total time=   5.2s
# [CV 8/10; 9/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd
# [CV 7/10; 9/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd;, score=0.504 total time=   5.2s
# [CV 9/10; 9/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd
# [CV 8/10; 9/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd;, score=0.574 total time=   7.5s
# [CV 10/10; 9/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd
# [CV 9/10; 9/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd;, score=0.456 total time=   7.4s
# [CV 1/10; 10/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam
# [CV 10/10; 9/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd;, score=0.474 total time=   5.4s
# [CV 2/10; 10/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam
# [CV 1/10; 10/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam;, score=0.617 total time=   5.8s
# [CV 3/10; 10/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam
# [CV 2/10; 10/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam;, score=0.609 total time=   9.1s
# [CV 4/10; 10/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam
# [CV 3/10; 10/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam;, score=0.696 total time=   9.9s
# [CV 5/10; 10/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam
# [CV 4/10; 10/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam;, score=0.530 total time=   6.9s
# [CV 6/10; 10/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam
# [CV 5/10; 10/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam;, score=0.591 total time=   5.7s
# [CV 7/10; 10/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam
# [CV 6/10; 10/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam;, score=0.643 total time=   5.5s
# [CV 8/10; 10/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam
# [CV 7/10; 10/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam;, score=0.722 total time=   6.8s
# [CV 9/10; 10/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam
# [CV 8/10; 10/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam;, score=0.696 total time=   8.0s
# [CV 10/10; 10/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam
# [CV 9/10; 10/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam;, score=0.596 total time=   7.0s
# [CV 1/10; 11/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd
# [CV 10/10; 10/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam;, score=0.596 total time=   5.6s
# [CV 2/10; 11/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd
# [CV 1/10; 11/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd;, score=0.496 total time=   5.2s
# [CV 3/10; 11/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd
# [CV 2/10; 11/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd;, score=0.383 total time=   7.2s
# [CV 4/10; 11/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd
# [CV 3/10; 11/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd;, score=0.470 total time=   7.5s
# [CV 5/10; 11/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd
# [CV 4/10; 11/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd;, score=0.348 total time=   5.2s
# [CV 6/10; 11/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd
# [CV 5/10; 11/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd;, score=0.409 total time=   5.0s
# [CV 7/10; 11/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd
# [CV 6/10; 11/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd;, score=0.487 total time=   6.1s
# [CV 8/10; 11/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd
# [CV 7/10; 11/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd;, score=0.504 total time=   7.4s
# [CV 9/10; 11/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd
# [CV 8/10; 11/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd;, score=0.574 total time=   6.3s
# [CV 10/10; 11/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd
# [CV 9/10; 11/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd;, score=0.456 total time=   5.2s
# [CV 1/10; 12/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam
# [CV 10/10; 11/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd;, score=0.474 total time=   5.1s
# [CV 2/10; 12/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam
# [CV 1/10; 12/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam;, score=0.617 total time=   5.6s
# [CV 3/10; 12/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam
# [CV 2/10; 12/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam;, score=0.609 total time=   8.0s
# [CV 4/10; 12/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam
# [CV 3/10; 12/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam;, score=0.696 total time=   7.5s
# [CV 5/10; 12/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam
# [CV 4/10; 12/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam;, score=0.530 total time=   5.8s
# [CV 6/10; 12/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam
# [CV 5/10; 12/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam;, score=0.591 total time=   5.6s
# [CV 7/10; 12/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam
# [CV 6/10; 12/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam;, score=0.643 total time=   7.8s
# [CV 8/10; 12/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam
# [CV 7/10; 12/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam;, score=0.722 total time=   7.6s
# [CV 9/10; 12/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam
# [CV 8/10; 12/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam;, score=0.696 total time=   5.5s
# [CV 10/10; 12/48] START activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam
# [CV 9/10; 12/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam;, score=0.596 total time=   5.6s
# [CV 1/10; 13/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd
# [CV 10/10; 12/48] END activation=relu, alpha=0.001, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam;, score=0.596 total time=   6.8s
# [CV 2/10; 13/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd
# [CV 1/10; 13/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd;, score=0.496 total time=   6.9s
# [CV 3/10; 13/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd
# [CV 2/10; 13/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd;, score=0.461 total time=   6.8s
# [CV 4/10; 13/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd
# [CV 3/10; 13/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd;, score=0.478 total time=   6.0s
# [CV 5/10; 13/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd
# [CV 4/10; 13/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd;, score=0.426 total time=   5.4s
# [CV 6/10; 13/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd
# [CV 5/10; 13/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd;, score=0.400 total time=   5.6s
# [CV 7/10; 13/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd
# [CV 6/10; 13/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd;, score=0.496 total time=   7.6s
# [CV 8/10; 13/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd
# [CV 7/10; 13/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd;, score=0.557 total time=   7.3s
# [CV 9/10; 13/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd
# [CV 8/10; 13/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd;, score=0.557 total time=   5.5s
# [CV 10/10; 13/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd
# [CV 9/10; 13/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd;, score=0.500 total time=   5.4s
# [CV 1/10; 14/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam
# [CV 10/10; 13/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=sgd;, score=0.553 total time=   7.7s
# [CV 2/10; 14/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam
# [CV 1/10; 14/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam;, score=0.661 total time=   8.4s
# [CV 3/10; 14/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam
# [CV 2/10; 14/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam;, score=0.574 total time=   5.9s
# [CV 4/10; 14/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam
# [CV 3/10; 14/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam;, score=0.626 total time=   6.0s
# [CV 5/10; 14/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam
# [CV 4/10; 14/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam;, score=0.565 total time=   8.0s
# [CV 6/10; 14/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam
# [CV 5/10; 14/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam;, score=0.522 total time=   8.3s
# [CV 7/10; 14/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam
# [CV 6/10; 14/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam;, score=0.609 total time=   6.2s
# [CV 8/10; 14/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam
# [CV 7/10; 14/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam;, score=0.730 total time=   6.0s
# [CV 9/10; 14/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam
# [CV 8/10; 14/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam;, score=0.661 total time=  10.3s
# [CV 10/10; 14/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam
# [CV 9/10; 14/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam;, score=0.640 total time=  10.4s
# [CV 1/10; 15/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd
# [CV 10/10; 14/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=adaptive, solver=adam;, score=0.632 total time=   6.2s
# [CV 2/10; 15/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd
# [CV 1/10; 15/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd;, score=0.496 total time=   5.4s
# [CV 3/10; 15/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd
# [CV 2/10; 15/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd;, score=0.461 total time=   6.8s
# [CV 4/10; 15/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd
# [CV 3/10; 15/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd;, score=0.478 total time=   7.1s
# [CV 5/10; 15/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd
# [CV 4/10; 15/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd;, score=0.426 total time=   6.6s
# [CV 6/10; 15/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd
# [CV 5/10; 15/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd;, score=0.400 total time=   6.4s
# [CV 7/10; 15/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd
# [CV 6/10; 15/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd;, score=0.496 total time=   5.1s
# [CV 8/10; 15/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd
# [CV 7/10; 15/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd;, score=0.557 total time=   5.7s
# [CV 9/10; 15/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd
# [CV 8/10; 15/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd;, score=0.557 total time=   7.6s
# [CV 10/10; 15/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd
# [CV 9/10; 15/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd;, score=0.500 total time=   7.7s
# [CV 1/10; 16/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam
# [CV 10/10; 15/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=sgd;, score=0.553 total time=   5.5s
# [CV 2/10; 16/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam
# [CV 1/10; 16/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam;, score=0.661 total time=   5.9s
# [CV 3/10; 16/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam
# [CV 2/10; 16/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam;, score=0.574 total time=   8.0s
# [CV 4/10; 16/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam
# [CV 3/10; 16/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam;, score=0.626 total time=   8.3s
# [CV 5/10; 16/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam
# [CV 4/10; 16/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam;, score=0.565 total time=   5.9s
# [CV 6/10; 16/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam
# [CV 5/10; 16/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam;, score=0.522 total time=   6.0s
# [CV 7/10; 16/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam
# [CV 6/10; 16/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam;, score=0.609 total time=   7.8s
# [CV 8/10; 16/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam
# [CV 7/10; 16/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam;, score=0.730 total time=   8.1s
# [CV 9/10; 16/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam
# [CV 8/10; 16/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam;, score=0.661 total time=   6.1s
# [CV 10/10; 16/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam
# [CV 9/10; 16/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam;, score=0.640 total time=   6.2s
# [CV 1/10; 17/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd
# [CV 10/10; 16/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(180,), learning_rate=constant, solver=adam;, score=0.632 total time=   7.2s
# [CV 2/10; 17/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd
# [CV 1/10; 17/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd;, score=0.530 total time=  10.0s
# [CV 3/10; 17/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd
# [CV 2/10; 17/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd;, score=0.435 total time=   9.0s
# [CV 4/10; 17/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd
# [CV 3/10; 17/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd;, score=0.496 total time=   8.2s
# [CV 5/10; 17/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd
# [CV 4/10; 17/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd;, score=0.417 total time=  10.1s
# [CV 6/10; 17/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd
# [CV 5/10; 17/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd;, score=0.452 total time=   9.7s
# [CV 7/10; 17/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd
# [CV 6/10; 17/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd;, score=0.557 total time=   8.1s
# [CV 8/10; 17/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd
# [CV 7/10; 17/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd;, score=0.548 total time=   9.8s
# [CV 9/10; 17/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd
# [CV 8/10; 17/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd;, score=0.548 total time=   9.8s
# [CV 10/10; 17/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd
# [CV 9/10; 17/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd;, score=0.491 total time=   8.0s
# [CV 1/10; 18/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam
# [CV 10/10; 17/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=sgd;, score=0.544 total time=  10.1s
# [CV 2/10; 18/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam
# [CV 1/10; 18/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam;, score=0.643 total time=  10.4s
# [CV 3/10; 18/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam
# [CV 2/10; 18/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam;, score=0.626 total time=   8.6s
# [CV 4/10; 18/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam
# [CV 3/10; 18/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam;, score=0.652 total time=  10.6s
# [CV 5/10; 18/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam
# [CV 4/10; 18/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam;, score=0.600 total time=  10.8s
# [CV 6/10; 18/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam
# [CV 5/10; 18/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam;, score=0.617 total time=   9.9s
# [CV 7/10; 18/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam
# [CV 6/10; 18/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam;, score=0.661 total time=  12.8s
# [CV 8/10; 18/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam
# [CV 7/10; 18/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam;, score=0.739 total time=  11.8s
# [CV 9/10; 18/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam
# [CV 8/10; 18/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam;, score=0.661 total time=   9.2s
# [CV 10/10; 18/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam
# [CV 9/10; 18/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam;, score=0.711 total time=  10.6s
# [CV 1/10; 19/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd
# [CV 10/10; 18/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=adaptive, solver=adam;, score=0.658 total time=  10.0s
# [CV 2/10; 19/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd
# [CV 1/10; 19/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd;, score=0.530 total time=   7.7s
# [CV 3/10; 19/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd
# [CV 2/10; 19/48] END activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd;, score=0.435 total time=   9.8s
# [CV 4/10; 19/48] START activation=relu, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd
# ...
# [CV 2/10; 43/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd;, score=0.270 total time=  10.9s
# [CV 4/10; 43/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd
# [CV 3/10; 43/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd;, score=0.322 total time=  10.1s
# [CV 5/10; 43/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd
# [CV 4/10; 43/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd;, score=0.226 total time=   9.5s
# [CV 6/10; 43/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd
# [CV 5/10; 43/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd;, score=0.348 total time=  10.7s
# [CV 7/10; 43/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd
# [CV 6/10; 43/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd;, score=0.313 total time=  10.0s
# [CV 8/10; 43/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd
# [CV 7/10; 43/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd;, score=0.357 total time=  10.6s
# [CV 9/10; 43/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd
# [CV 8/10; 43/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd;, score=0.409 total time=  10.2s
# [CV 10/10; 43/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd
# [CV 9/10; 43/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd;, score=0.325 total time=   8.7s
# [CV 1/10; 44/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam
# [CV 10/10; 43/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=sgd;, score=0.351 total time=  10.3s
# [CV 2/10; 44/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam
# [CV 1/10; 44/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam;, score=0.557 total time=  11.6s
# [CV 3/10; 44/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam
# [CV 2/10; 44/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam;, score=0.487 total time=  10.2s
# [CV 4/10; 44/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam
# [CV 3/10; 44/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam;, score=0.487 total time=  11.4s
# [CV 5/10; 44/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam
# [CV 4/10; 44/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam;, score=0.417 total time=  11.3s
# [CV 6/10; 44/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam
# [CV 5/10; 44/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam;, score=0.426 total time=  11.3s
# [CV 7/10; 44/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam
# [CV 6/10; 44/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam;, score=0.487 total time=  11.3s
# [CV 8/10; 44/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam
# [CV 7/10; 44/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam;, score=0.557 total time=   9.3s
# [CV 9/10; 44/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam
# [CV 8/10; 44/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam;, score=0.600 total time=  11.6s
# [CV 10/10; 44/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam
# [CV 9/10; 44/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam;, score=0.509 total time=  13.2s
# [CV 1/10; 45/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd
# [CV 10/10; 44/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(300,), learning_rate=constant, solver=adam;, score=0.544 total time=  12.8s
# [CV 2/10; 45/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd
# [CV 1/10; 45/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd;, score=0.165 total time=   6.2s
# [CV 3/10; 45/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd
# [CV 2/10; 45/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd;, score=0.139 total time=   4.0s
# [CV 4/10; 45/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd
# [CV 3/10; 45/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd;, score=0.087 total time=   4.1s
# [CV 5/10; 45/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd
# [CV 4/10; 45/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd;, score=0.157 total time=   3.5s
# [CV 6/10; 45/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd
# [CV 5/10; 45/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd;, score=0.139 total time=   3.7s
# [CV 7/10; 45/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd
# [CV 6/10; 45/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd;, score=0.122 total time=   4.2s
# [CV 8/10; 45/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd
# [CV 7/10; 45/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd;, score=0.252 total time=   7.8s
# [CV 9/10; 45/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd
# [CV 8/10; 45/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd;, score=0.130 total time=   5.5s
# [CV 10/10; 45/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd
# [CV 9/10; 45/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd;, score=0.132 total time=   3.1s
# [CV 1/10; 46/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam
# [CV 10/10; 45/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=sgd;, score=0.149 total time=   4.3s
# [CV 2/10; 46/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam
# [CV 1/10; 46/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam;, score=0.461 total time=   6.6s
# [CV 3/10; 46/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam
# [CV 2/10; 46/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam;, score=0.452 total time=   7.7s
# [CV 4/10; 46/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam
# [CV 3/10; 46/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam;, score=0.487 total time=   7.6s
# [CV 5/10; 46/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam
# [CV 4/10; 46/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam;, score=0.435 total time=   6.3s
# [CV 6/10; 46/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam
# [CV 5/10; 46/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam;, score=0.452 total time=   6.8s
# [CV 7/10; 46/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam
# [CV 6/10; 46/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam;, score=0.522 total time=   7.9s
# [CV 8/10; 46/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam
# [CV 7/10; 46/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam;, score=0.461 total time=   7.4s
# [CV 9/10; 46/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam
# [CV 8/10; 46/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam;, score=0.504 total time=   6.6s
# [CV 10/10; 46/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam
# [CV 9/10; 46/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam;, score=0.447 total time=   6.4s
# [CV 1/10; 47/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd
# [CV 10/10; 46/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=adaptive, solver=adam;, score=0.518 total time=   7.6s
# [CV 2/10; 47/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd
# [CV 1/10; 47/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd;, score=0.165 total time=   4.5s
# [CV 3/10; 47/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd
# [CV 2/10; 47/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd;, score=0.139 total time=   2.4s
# [CV 4/10; 47/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd
# [CV 4/10; 47/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd;, score=0.165 total time=   1.7s
# [CV 5/10; 47/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd
# [CV 3/10; 47/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd;, score=0.113 total time=   2.4s
# [CV 6/10; 47/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd
# [CV 5/10; 47/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd;, score=0.139 total time=   2.1s
# [CV 7/10; 47/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd
# [CV 6/10; 47/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd;, score=0.139 total time=   2.4s
# [CV 8/10; 47/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd
# [CV 8/10; 47/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd;, score=0.165 total time=   2.5s
# [CV 9/10; 47/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd
# [CV 9/10; 47/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd;, score=0.167 total time=   1.5s
# [CV 10/10; 47/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd
# [CV 7/10; 47/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd;, score=0.252 total time=   6.1s
# [CV 1/10; 48/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam
# [CV 10/10; 47/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=sgd;, score=0.123 total time=   4.2s
# [CV 2/10; 48/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam
# [CV 1/10; 48/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam;, score=0.461 total time=   7.8s
# [CV 3/10; 48/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam
# [CV 2/10; 48/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam;, score=0.452 total time=   6.6s
# [CV 4/10; 48/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam
# [CV 3/10; 48/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam;, score=0.487 total time=   6.0s
# [CV 5/10; 48/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam
# [CV 4/10; 48/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam;, score=0.435 total time=   7.1s
# [CV 6/10; 48/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam
# [CV 5/10; 48/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam;, score=0.452 total time=   8.5s
# [CV 7/10; 48/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam
# [CV 6/10; 48/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam;, score=0.522 total time=   7.3s
# [CV 8/10; 48/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam
# [CV 7/10; 48/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam;, score=0.461 total time=   6.2s
# [CV 9/10; 48/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam
# [CV 8/10; 48/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam;, score=0.504 total time=   6.7s
# [CV 10/10; 48/48] START activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam
# [CV 9/10; 48/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam;, score=0.447 total time=   8.3s
# [CV 10/10; 48/48] END activation=logistic, alpha=0.01, hidden_layer_sizes=(100, 50), learning_rate=constant, solver=adam;, score=0.518 total time=   7.0s
# Best parameters found:
#  {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'solver': 'adam'}

# %% [markdown]
# #### RELU Activation Function
# Grid search chose the (Rectified Linear Unit) relu function as the best activation function The function returns 0 if it receives any negative input, but for any positive value  x, it returns that value back. So it can be written as  f(x)=max(0,x). While our **hidden layer use the relu function** for its activation on each neuron, our **output layer will necessarily use the softmax function** - an exponential normalization function - in order to scale output neuron values to a probability between \[0,1\] for each class (emotion). Softmax does this normalization by taking the exponent of the value of each output neuron and dividing that by sum of the exponentiated output values, producing _n_ probabilities for _n_ classes. We then choose the highest probability as the predicted class for a set of input features. To be clear, **softmax activation is applied to the values of _all_ output neurons _once_ - not to each neuron.**
#
# #### Adam Optimization Algorithm
# The solver chosen is the **Adam optimization** algorithm, a variant of **stochastic gradient descent** (SGD). Unlike SGD, which maintains a constant learning rate throughout each training iteration, Adam actually 'adapts', or varies the learning rate by taking into account the moving averages of the first and second moments (mean and variance) of the gradient at each training iteration. It makes sense that grid search chose the more sophisticated algorithm - note however it's not necessarily better than SGD for all tasks.
#
# #### Architecture
# As expected, the ideal architechture involves just one hidden layer - though with double the neurons we expected for 180 features. Training the 2 and 3 hidden layer models was extremely computationally expensive compared to 1 hidden layer - and provided absolutely no benefit, only complexity and wasted resources. A good reinforcement of the power of simplicity, especially in deep neural networks. In the domain of model simplicity, there is also a compelling argument to be made for interpretability (to the point a model should _never_ be a black box) ...but that's for another time.
#
# We can now initialize our MLP model with the best hyperparameters for the task of speech emotion classification.

# %% [markdown]
# ## Training and Evaluating the MLP Model

# %%
# declare again so I don't have to re-run gridsearch when I restart the jupyter kernel
# our default X_train, X_test are now standard scaled features since we know they're best
X_train, X_test, y_train, y_test = train_test_split(
    features_scaled,
    emotions,
    test_size=0.2,
    random_state=69
)

model = MLPClassifier(
    activation='relu',
    solver='adam',
    alpha=0.001,
    batch_size=256,
    hidden_layer_sizes=(300,),
    learning_rate='adaptive',
    max_iter=1000, # I've found for this task, loss converges at ~1000 iterations
    random_state=69,
)

model.fit(X_train, y_train)

print(f'MLP Model\'s accuracy on training set is {100*model.score(X_train, y_train):.2f}%')
print(f'MLP Model\'s accuracy on test set is {100*model.score(X_test, y_test):.2f}%')
# Out:
# MLP Model's accuracy on training set is 100.00%
# MLP Model's accuracy on test set is 69.34%

# %% [markdown]
# That's a little better - but not great. That's expected, because most of the hyperparameters chosen by grid search are default with sklearn's MLP. At any rate, our MLP model is **overfitting the training data and not generalizing well to the test set**. With the near-perfect training accuracy it's clear our model's loss function is converging - let's see:

# %%
plt.figure()
plt.plot([num for num in range(1,model.n_iter_ +1)], model.loss_curve_)
plt.title('Loss Curve for MLP Model')
plt.ylabel('Loss')
plt.xlabel('Iteration')
plt.show()

# %% [markdown]
# **Loss is indeed converging, and it appears to be a good learning rate - we want to avoid too high a learning rate since the model will bias data towards the last batches passed through it, and avoid too slow a learning rate because our model will take too long to converge.** Because of its perfect performance on the training data and poor performance on test data, we at this point suspect our model has too high a variance: It's learning to fit its weights so precisely to the training data to score well on it that its performance doesn't extend past that training data. If we had seen poor performance on both training and test sets, we would suspect our model to have a high bias.
#
# **To solve high variance, wherein our model is overfitting to noise present in the training data, we can decrease the number of input features and/or increase the size of the training set** so our model has more data to learn on and can generalize better to data it has not seen. **We can also use data regularization, using data augmentation techniques such as the addition of random noise to the audio samples.** Data regularization is different from weight regularization, but they work towards the same purpose of reducing overfitting.
#
# **To solve high bias, wherein our model is underfitting to the data, we could increase the number of input features** so that it can learn a better fit to the underlying data.
#
# **High variance makes the model's predictions inconsistent**, while **high bias makes them inaccurate** and vice versa, respectively. Ultimately, we aim to make a model that is both accurate and consistent: low variance and low bias with good performance. There is almost always a trade-off between the two.

# %% [markdown]
# ### The Confusion Matrix
# A confusion matrix describes the performance of a classification model on test data. The axes of the matrix are labelled with all possible classes, in our case emotions - **the vertical levels/ columns represents predicted classes while the horizontal levels/rows represents the ground truth. The intersection of emotions on the matrix diagonal are correctly predicted labels.** All off-diagonal elements are incorrect predictions. We are literally checking to see where our model is confused, i.e. making incorrect predictions:

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn # I like seaborn's confusion matrix over sklearn's default

# get predictions on test set
test_emotion_predictions = model.predict(X_test)
test_emotion_groundtruth = y_test

# set labels for matrix axes from emotions
emotion_list =['neutral','calm','happy','sad','angry','fearful','disgust','surprised']
emotion_name = [emotion for emotion in emotion_list]

# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(test_emotion_groundtruth, test_emotion_predictions, labels=emotion_list)
conf_matrix_norm = confusion_matrix(test_emotion_groundtruth, test_emotion_predictions,normalize='true', labels=emotion_list)



# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_name, columns=emotion_name)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_name, columns=emotion_name)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

plt.show()

# %% [markdown]
# The sum of elements in the left matrix is size of our test set, which is the length of y_test. That should be 0.2*1435 = 287. The matrix on the right shows each element as a percentage of samples in that class. Each row adds up to 100%, i.e. each row represents all samples of a particular emotion.
#
# **We can tell the model is most accurate at predicting 'calm', and least accurate at predicting 'happy'**. Based on this we might look into our features to see where they are not distinct enough between confusing classes and whether we can rethink our feature engineering.

# %% [markdown]
# ### Precision, Recall, F-Score
# The confusion matrix is an intuitive measure of the precision and recall of our model w.r.t. each class. **Precision is a measure of how many positive predictions are true positives, and recall is a measure of how many positives we actually predicted from all positive samples in the dataset: Lower precision means we have more false positives, while lower recall means we have more false negatives.** For this dataset, precision of each emotion is how often we correctly predict it  and recall is how many of that emotion we predicted out of all samples with that emotion in the dataset.
#
# **Some tasks are more concerned with maximizing precision - minimizing false positives - such as predicting whether a prisoner is likely to reoffend if paroled.** It is [catastrophic](https://www.technologyreview.com/2019/01/21/137783/algorithms-criminal-justice-ai/) to deny an inmate parole due to a false positive.
#
# **Some tasks are more concerned with maximizing recall - minimizing false negatives - such as predicting cancer risk from biomarkers.** It is better to inconvenience 10 people with a false positive test so we can catch the 1 true positive who would otherwise have been a false negative, rather than skip the 11 tests altogether (with 10 true negatives and 1 false negative).
#
# **The [F-score](https://en.wikipedia.org/wiki/F1_score) is a weighted average of precision and recall when we are equally concerned with both metrics.**
#
# **We can also make an [ROC curve](https://en.wikipedia.org/wiki/Receiver_operating_characteristic#:~:text=A%20receiver%20operating%20characteristic%20curve,why%20it%20is%20so%20named.) by plotting True Positive vs False Positive Rate to visualize their trade-off and make considerations for further tuning.** However, ROC curves are usually plotted for binary classification; doing so for

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

y_pred = model.predict(X_test)
print(f'Test Set Accuracy score =  {100*accuracy_score(y_test, y_pred):.3f}%') #same as model.score(X_test, y_test)
print(f'Test Set Precision score =  {100*precision_score(y_test, y_pred, average="macro"):.3f}%')
print(f'Test Set Recall score =  {100*recall_score(y_test, y_pred, average="macro"):.3f}%')
print(f'Test Set F-score score =  {100*f1_score(y_test, y_pred, average="macro"):.3}%')
# Out:
# Test Set Accuracy score =  69.338%
# Test Set Precision score =  69.022%
# Test Set Recall score =  69.089%
# Test Set F-score score =  68.7%

# %% [markdown]
# **Pretty balanced across the board - about the same false positive rate and false negative rate.**

# %% [markdown]
# ### K-Fold Cross-Validation
# To highlight the importance of proper model validation and get a better idea of our model's performance,
# we're going to use K-Fold Cross-Validation (K-Fold CV). We split our training dataset into _K_ unique validation sets (_K_ sets/folds) - the train/validation split being determined by _K_ where each _validation set = (100/K)%_ of the entire dataset, the training set being composed of the remaining _K-1_ validation sets. The term cross-validation refers to validating the model on multiple validation sets.
#
# The terminology here may be somewhat confusing, because we usually **split our 80% _training_ set into a _training_ and _validation_ set at each iteration of K-Fold CV.** We reserve the actual _test_ set - the one we made originally with an 80/20 split of the entire dataset - for checking our model's performance _after_ we have tuned its hyperparameters.
#
# In this way, K-Fold CV will train and score _K_ different versions of our classifier.
# Note that while training sets overlap (unless otherwise defined, e.g. sklearn's GroupKFold), validation sets never overlap.
# We'll use 10-fold CV, with _K=10_ being a choice giving average scores of models with fairly low bias and moderate variance due in part to the resulting 90/10 train/validation ratio.
#
# **K-Fold CV trains our model on _K=10_ different, overlapping training folds and check its performance against _K=10_ validation folds.**
#
# Smaller datasets would theoretically be better scored with **higher _K_,** meaning we will have a larger portion of our dataset in training sets and a greater overlap of training samples between folds - this way we better represent a small dataset, have more training data, and hopefully provide a **better estimate of the model's true generalization error**, though at the cost of **higher variance because the _K_ estimates of our model's performance are correlated** (though there are exceptions). In the extreme case, and for computationally inexpensive models, **leave-one-out K-Fold CV (LOOCV)** can be used to construct training folds consisting of all samples-1, and 1 sample with in the validation fold; _each training fold differs by just 1 sample_ and this method provides adequate training data for each model validation on smaller training datasets.
#
# Sine we're training a classifier, we use **StratifiedKFold which preserves the percentage of samples in each class** (emotion) for each fold. Although we have a balanced dataset, Stratified K-Fold CV is especially important when classifying an imbalanced dataset. We also set shuffle=True to shuffle the order of sample classes in each fold to match the default behaviour of sklearn's train_test_split so we can accurately compare that to the K-Fold CV score.
#
# Choose _K_ for our K-Fold CV and train the MLP classifier on each set of train/validation folds:

# %%
from sklearn.model_selection import StratifiedKFold

kfold = StratifiedKFold(
    n_splits=10,
    random_state=69,
    shuffle=True
)

scores = []
X_train=pd.DataFrame(X_train)
y_train=pd.DataFrame(y_train)
for train_indices, test_indices in kfold.split(X_train,y_train):



    train_x=X_train.iloc[train_indices]
    train_y=y_train.iloc[train_indices]

    test_x=X_train.iloc[test_indices]
    test_y=y_train.iloc[test_indices]
    # fit model to training fold
    model.fit(train_x, train_y)
    # score the model on validation fold
    scores.append(model.score(test_x, test_y))

print('KFold CV scores for MLP:');[print(f'{(100*score):.2f}%') for score in scores]
print(f'Mean score of KFold CV for MLP: {100*np.mean(scores):.2f}% ± {100*np.std(scores):.2f}%')
# Out:
# KFold CV scores for MLP:
# 71.30%
# 71.30%
# 64.35%
# 66.96%
# 68.70%
# 67.83%
# 66.96%
# 68.70%
# 62.28%
# 63.16%
# Mean score of KFold CV for MLP: 67.15% ± 2.96%

# %% [markdown]
# Indeed, quite a bit worse, but a more accurate evaluation of this model. **Because we get considerably worse performance fitting our model on random subsets of our training data, we could surmise that our model's performance is inflated by overfitting** when we train and test it just once on a regular 80/20 split.
#
# Although K-Fold CV is computationally expensive, we're getting a lot more insight out of our data and that's a serious advantage when we have very few training samples. Tuning a model to just one validation set, such as in a 60/20/20 split may provide artifically inflated performance metrics which will disappoint when the model is applied to real-world data.

# %% [markdown]
# We can use a learning curve to compare the performance of our model if we had trained it on smaller subsets of our training dataset, and thus get an idea of whether we might expect a performance increase by using more training data, or much less likely that we don't need as much data.
#
# We specify variable sizes of training sets to use for the learning curve to make one model for each size. Remember that since we're using 0.8\*1440 = 1152 samples in our training set, that is the upper bound that the learning curve can check for us. Like the validation curve, sklearn's learning curve implements Stratified K-Fold CV to evaluate multiclass classification models, so again we specify _K = 10_.

# %%
from sklearn.model_selection import learning_curve

# Build learning curve
train_sizes, train_scores, test_scores = learning_curve(
    model,
    X=X_train,
    y=y_train,
    cv=10,
    shuffle=True,
    random_state=69,
    n_jobs=4,
    # We have (0.8*1440)/10 = 115/1150 training samples, 1035/1150 test samples
    train_sizes=[10,100,300,500,800, 1000] # bounded at 1035 for this dataset for 10-fold cv
)
# Get errors for learning curve
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

# Plot learning curve
plt.figure()
plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1,
                     color="g")
plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")
plt.title('Learning Curve for MLP Model')
plt.xlabel('Number of Training Samples')
plt.ylabel('Score')
plt.legend(loc="best")
plt.show()

# %% [markdown]
# One thing the learning curve tells us is that the size of the dataset isn't our biggest issue - our **accuracy is plateauing and wouldn't seriously benefit from a larger training set** - maybe 5% at most with a gigantic dataset. Again, the gap between the training score curve and cross-validation score curve shows us that the model has an extremely high variance and - it scores perfectly on training data but poorly in cross-validation because it is seriously overfit - the model does not generalize well at all on test data.
#
# It has become clear that an MLP network may not be the best choice of model for this task - it seems to not have the complexity we would need to properly discriminate the differences between our features w.r.t. emotion. It appears at this point that we would need a considerably more sophisticated deep neural net to get better performance on this dataset.

# %% [markdown]
# ## Conclusion
#
# The MLPClassifier is powerful in that it achieves appreciable performance with relatively little effort invested in exploratory analysis, hyperparameter optimization, and model architechture; especially taking advantage of grid search, and much more so when we know how to tune each hyperparameter individually.
#
# We're going to have to explore more complicated deep learning methods to get real performance on this dataset. **Long-Short-Term-Memory Recurrent Neural Networks (LSTM RNNs) and Convolutional Neural Networks (CNNs) are excellent DNN candidates for audio data classification: LSTM RNNs because of their excellent ability to interpret sequential data such as the audio waveform represented as a time series; CNNs because features engineered on audio data such as spectrograms have marked resemblance to images, in which CNNs excel at recognizing and discriminating between distinct patterns.**
#
#
# If you got this far, I sincerely appreciate your taking the time to do so. Feel free to drop a line at ilzenkov@gmail.com with any feedback you may have. HE isthe actual author of all these notebooks.
